# %% [markdown]
# # Fundamentals of Data Science
# Winter Semester 2021
#
# ## Prof. Fabio Galasso, Guido D'Amely, Alessandro Flaborea, Luca Franco, Muhammad Rameez Ur Rahman and Alessio Sampieri
# <galasso@di.uniroma1.it>, <damely@di.uniroma1.it>, <flaborea.1841969@studenti.uniroma1.it>, <franco.luca.17@gmail.com>, <rahman@di.uniroma1.it>, <alessiosampieri27@gmail.com>
#
# ## Exercise 1: Image Filtering and Object Identification

# %% [markdown]
# In this exercise you will first familiarise yourself with the basic image filtering routines of Python and NumPy (**Question 1**), then develop a simple image querying system which accepts a query image as input and then finds a set of similar images in the database (**Question 2, 3 and 4**).
#
# This notebook consists of essential functions to solve assignment and questions to be implemented; your task is to fill the missing code "YOUR CODE HERE" part corresponding to each subproblem and produce brief reports on the results whenever necessary.
#
# The filtering part contains two images: *graph.png* and *brick_aliasing.jpg*, which we will use for testing purposes.
#
# In the identification part, you will compare images with several distance functions and evaluate their performance in combination with different image representations. The identification part contains query and model images
# for the evaluation, which correspond to the same set of objects photographed from different viewpoints. The files model.txt and query.txt contain lists of image files arranged so that i-th model image depicts the same object as i-th query image. The placeholder scripts will also be used to test your solution.
#
# As part of the exercise, provide an answer to questions in this notebook, in a report-like manner. After you have implemented all the missing code in both exercise parts, you should be able to execute those without errors. Use those to support your answers in the report answers.
#
# The completed exercise should be handed in as a single notebook file. Use Markdown to provide equations. Use the code sections to provide your scripts and the corresponding plots.
# Submit it by sending an email to galasso@di.uniroma1.it, damely@di.uniroma1.it, rahman@di.uniroma1.it and alessiosampieri27@gmail.com by Wednesday October 20th, 23:59.

# %% [markdown]
# ## Question 1: Image Filtering **(9 Points)**

# %% [markdown]
# Import some useful libraries

# %%
## import packages
import numpy as np
from PIL import Image
from scipy.signal import convolve2d as conv2, convolve
import matplotlib.pyplot as plt
import cv2
import math
import random

plt.rcParams["figure.figsize"] = (20,8)

# %%
def rgb2gray(rgb):
  '''
  RGB -> gray_scale
  '''
  r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
  gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
  return gray

# %% [markdown]
# ### Exercise 1 - Code **(7 Points)**

# %% [markdown]
# #### Exercise 1.a **(3 Points)**

# %% [markdown]
# ##### 1-D Gaussian Filter
# Implement a method which computes the values of a 1-D Gaussian *Gx* for a given standard deviation $\sigma$ :
# \begin{equation}
# G=\frac{1}{\sqrt{2\pi}\sigma}\exp(-\frac{x^2}{2\sigma^2})
# \end{equation}
#
# The method should also return a vector *x* of values on which the Gaussian filter is defined: integer values on the interval $\left[-3\sigma,3\sigma\right]$.
#
# This should be the output with $\sigma=3$.
#
#
# ![](https://drive.google.com/uc?export=view&id=1Q3WIdozsroKzinnlyZhgZHFMdYj7KQrw)

# %%
def gauss(sigma):
  """
  Gauss function taking as argument the standard deviation sigma
  The filter should be defined for all integer values x in the range [-3sigma,3sigma]
  The function should return the Gaussian values Gx computed at the indexes x
  """
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
    
  x = np.linspace(-3*sigma,3*sigma,19)
  Gx = (1/(math.sqrt(2*math.pi) * sigma)) * (math.e ** (-1 * (x ** 2 / (2 * (sigma ** 2)))))
  return Gx, x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function gauss
sigma = 3
Gx,x = gauss(sigma)
plt.figure(1)
plt.plot(x, Gx, '.-')
plt.show()

# %% [markdown]
# ##### 1-D Box Filter
#
# Implement a method which computes the values of a 1-D Box *Bx* for a given standard deviation $\sigma$ :
# \begin{equation}
# B= [\frac{1}{n},\frac{1}{n},\dots,\frac{1}{n}]\in \mathbb{R}^n
# \end{equation}
#
# The method should also return a vector *x* of values on which the **Box** filter is defined: integer values on the interval $\left[-3\sigma,3\sigma\right]$.
#
# An example of Box Filter:
#
# ![](https://drive.google.com/uc?export=view&id=1UBpSRYNkZnK2UGmGsMSnrmzwrPyMt6Fz)

# %%
def box(filter_size=3,show_verbose=False):
    """
    box function taking as argument the filter size.
    The filter should be defined for all integer values and centered at zero
    The function should return the Box values Bx computed at the indexes x
    """
    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    
    x = np.linspace(-3*sigma,3*sigma,filter_size)
    Bx = np.array([1/filter_size for i in range(filter_size)])
    
    return Bx,x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function box
size = 3
Bx,x = box(size)
plt.figure(1)
plt.plot(x, Bx, '.-')
plt.show()

# %% [markdown]
# ##### 2-D custom filter
# Recreate the given 3x3 filter:
#
# \begin{bmatrix}
# -0.015 & -0.035 & -0.015\\
# -0.035 & 0.8 &  -0.035 \\
# -0.015 & -0.035 & -0.015
# \end{bmatrix}
#
#  The absolute value of the elements in the kernel sum to 1, in the middle position we find 80% of the weights and in the corners 30% of the remaining percentage with negative sign.

# %%
def custom():
  """
  This function returns the shown kernel.
  """
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  Gx = np.array([[-0.015, -0.035, -0.015], [-0.035, 0.8, -0.035], [-0.015, -0.035, -0.015]])

  return Gx

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
custom_filter = custom()
print(custom_filter)
# Out:
# [[-0.015 -0.035 -0.015]
#  [-0.035  0.8   -0.035]
#  [-0.015 -0.035 -0.015]]

# %% [markdown]
# ##### Gauss derivative 1-D
# Implement a function gaussdx for creating a Gaussian derivative filter in 1D:
# $$
# \frac{d}{dx}G =-\frac{1}{\sqrt{2\pi}\sigma^3}x\exp({-\frac{x^2}{2\sigma^2}})
# $$
# As in 1.a-1.b, the function should also return a vector x of values on which the Gaussian derivative filter is
# defined: integer values on the interval $[3\sigma; 3\sigma]$.
#
# An example of Gauss derivative 1-D:
#
# ![](https://drive.google.com/uc?export=view&id=1QZmVMxJiOARKe5MoqzZ7SSSjFikoY2ty)

# %%
def gaussdx(sigma):

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  x = np.linspace(-3*sigma,3*sigma,20)
  Dx = - 1 * (1/(math.sqrt(2*math.pi) * (sigma**3))) * x * (math.e ** (-1 * (x ** 2 / (2 * (sigma ** 2)))))
  return Dx, x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function gaussdx
sigma = 3
DGx,x = gaussdx(sigma)
plt.figure(1)
plt.plot(x, DGx, '.-')
plt.show()

# %% [markdown]
# #### Exercise 1.b **(3 Points)**
#
# Here you have to convolve the filters you have just defined with the given image _'graf.png'_. Remember that "Box" and "Gaussian" filters are separable.

# %% [markdown]
# ##### 2-D Gaussian filter
# The function should take an image as an input
# and return the result of convolution of this image with 2D Gaussian kernel. You can take advantage of the Python’s convolve2D function if you don’t want to
# implement convolution yourself.
#
# See figure below for illustration
# of Gaussian filtering.
# ![](https://drive.google.com/uc?export=view&id=1GtsTZXlnj811pJi1VnamdtDCvhqHiu8j)

# %%
def gauss2d(sigma, N):
    x = np.arange(-N,N,0.5)
    x, y = np.meshgrid(x,x)
    gauss = 1 / (2*np.pi*sigma**2) * np.exp(-(x**2 + y **2)/(2*sigma**2))
    return gauss

# %%
def gaussfiltering(img, sigma):
  """
  Implement a 2D Gaussian filter, leveraging the previous gauss.
  Implement the filter from scratch or leverage the convolve or convolve2D methods (scipy.signal)
  Leverage the separability of Gaussian filtering
  Input: image, sigma (standard deviation)
  Output: smoothed image
  """
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  gaus = gauss2d(sigma,3)
  smooth_img = conv2(img, gaus)
  
  return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = gaussfiltering(img, 5)
#print(smooth_img.shape)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Gaussian Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ##### 2-D Box filter
# The function should take an image as an input
# and return the result of convolution of this image with 2D Box kernel.
#
# See figure below for illustration of Box filtering.
#
# ![Original Image](https://drive.google.com/uc?export=view&id=1IMrJUuTouVHmaiiyWB6H1QbKLzYTg9qC)

# %%
def box2d(N):
    x = np.array([1/N**2 for i in range(N)])
    x, y = np.meshgrid(x, x)
    return x

# %%
def boxfiltering(img, filter_size):
  """
  Implement a 2D Box filter, leveraging the previous box.
  Leverage the separability of Box filtering
  Input: image, filter_size
  Output: smoothed image
  """
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  box = box2d(24)
  smooth_img = conv2(img, box)
  return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = boxfiltering(img, 20)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Box Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ##### Custom Filter
#
# The function should take an image and return the result of the convolution of this image with the custom filter we have defined in exercise 1.a.
#
# See figure below for an illustration of this custom filter.
#
# ![](https://drive.google.com/uc?export=view&id=1N1wEkhqOuAX3TusQNNxN9KPOXb9nRsFn)

# %%
def customfiltering(img):
  """
  Implement a 2D Custom filter
  Implement the filter from scratch 
  Input: image
  Output: smoothed image
  """
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  cust = custom()
  smooth_img = conv2(img, cust)
  return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = customfiltering(img)
#print(smooth_img.shape)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Custom Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# #### Exercise 1.c **(1 Points)**
#
# Implement a Gaussian Pyramid: Write a function for downscaling (you can use the function [resize from cv2](https://docs.opencv.org/master/dd/d52/tutorial_js_geometric_transformations.html) library) and use the Gaussian filter to blur it. The Pyramid must consist of three steps:
#
# * Apply Gaussian filter on original Image
# * Resize (Downscale) the smoothed image (obtained from previous step) and apply Gaussian filter again.
# * Resize (Downscale) the smoothed image (obtained from previous step) and apply Gaussian filter again.
#
# See figure below for an illlustration of Gaussian Pyramid.
# ![](https://drive.google.com/uc?export=view&id=1JKeyNozWgoBWHqrUwj4SEF6SJEnO9uMt)

# %%
def downscale(img, factor):
  '''
  This function should return the given image
  resized by the factor.
  Input:
    img: the image to resize
    factor: the factor you want use to downscale
  Output:
    resized: the resized image
  '''
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  x, y = img.shape
  x = int(x * factor)
  y = int(y * factor)
  resized_img = cv2.resize(img, dsize = (x, y))
  return resized_img

# %%
def GaussianPyramid(img, steps=3, factor=0.5, sigma=4):
  '''
  This function implements the Gaussian Pyramid and shows the results.
  Leverage the "downscale" function.
  
  Inputs:
    img: the image
    steps: number of steps to use in performing the Pyramid
    factor: the scaling factor to resize the image at each step
    sigma: the Gaussian filter parameter
  
  Output:
    --
  '''
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
#   plt.imshow(img)

  
  for i in range(3):
    gauss = gaussfiltering(img, sigma)
    img = downscale(img, factor)
  plt.imshow(img)
    
  return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
GaussianPyramid(img)

# %% [markdown]
# ### Exercise 1 - Report **(2 Points)**
#
# Use the images from the previous exercises to write a report on what you learned about filters and convolutions **(in the text block below)**.
# In report, you should also compare your results: use the three filters you just created and apply on 'brick_aliasing.jpg' file and identify which filter is applied on Image A, Image B and Image C illustrated in Figure below. Use 7 as filter_size both for Gaussian and Box filter.
#
# ![](https://drive.google.com/uc?export=view&id=1eDOTU7FIRht9WMiAeW3ZlsFnpAlW_ZGm)

# %% [markdown]
# **Write your Report here**
#
#
# - Image A filter ->
# - Image B filter ->
# - Image C filter ->

# %% [markdown]
# ## Question 2: Identification **(10 Points)**

# %% [markdown]
# Import some useful libraries

# %%
## import packages
import numpy as np
from PIL import Image
from numpy import histogram as hist
import matplotlib.pyplot as plt

# %%
def rgb2gray(rgb):
  r, g, b = rgb[:, :, 0], rgb[:, :, 1], rgb[:, :, 2]
  gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
  return gray

# %% [markdown]
# ### Exercise 2 - Code

# %% [markdown]
# #### Exercise 2.a **(3 Points)**
# For this question,  implement the
# function **normalized hist**, which takes gray-value image as input and returns normalized histogram of
# pixel intensities. When quantizing the image to compute the histogram, consider that pixel intensities
# range in $[0, 255]$.
# Compare your implementation with built-in Python function numpy.histogram. Your histograms and
# histograms computed with Python should be approximately the same. (3 points)

# %%
def normalized_hist(img_gray, num_bins = 40, show_verbose = False):
  '''
  Compute histogram of image intensities, histogram should be normalized so that sum of all values equals 1
  assume that image intensity is between 0 and 255

  img_gray - input image in grayscale format
  num_bins - number of bins in the histogram

  '''
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  hists, bins = np.histogram(np.reshape(img_gray, img_gray.size), bins=num_bins, range=(0,255), density=True)
  return hists, bins

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img_color = np.array(Image.open('model/obj100__0.png'))
img_gray = rgb2gray(img_color.astype('double'))

plt.figure(1)
plt.subplot(1,3,1)
plt.imshow(img_gray,cmap='gray', vmin=0, vmax=255)

plt.subplot(1,3,2)
num_bins_gray = 40
hist_gray1, bin_gray1 = hist(img_gray.reshape(img_gray.size), num_bins_gray,(0,255))
plt.bar((bin_gray1[0:-1] + bin_gray1[1:])/2, hist_gray1, width=3)

plt.subplot(1,3,3)
hist_gray2, bin_gray2 = normalized_hist(img_gray, num_bins_gray)
plt.bar((bin_gray2[0:-1] + bin_gray2[1:])/2, hist_gray2, width=3)
plt.show()

# %% [markdown]
# # Exercise 2.b **(6 Points)**
# Implement the histogram types. Your implementation should
# complete the scripts provided in the functions rgb_hist, rg_hist and dxdy_hist.
# As above, when quantizing the images to compute the histogram, consider that “RGB” and “RG” range in
# $[0, 255]$. For the case of dxdy hist, the actual image value ranges depend on the chosen Gaussian filtering
# variance, used when computing the derivative. For this exercise, set the standard deviation $σ = 3.0$ and
# cap the pixel values to be in the range $[−6, 6]$, i.e. set all values below (above) the value of -6 (+6) to -6
# (+6). (3 points)

# %% [markdown]
# ##### RGB

# %%
def divide255(x):
    x[0] /= 255
    x[1] /= 255
    x[2] /= 255
    return x

def chooseBin(bins, n):
    for x in range(len(bins)-1):
        if (n >= bins[x] and n < bins[x+1]):
            return x
    return -1

# %%
def rgb_hist(img_color_double, num_bins = 10, show_verbose = False):
    '''
    Compute the *joint* histogram for each color channel in the image
    The histogram should be normalized so that sum of all values equals 1
    Assume that values in each channel vary between 0 and 255

    img_color - input color image
    num_bins - number of bins used to discretize each channel, total number of bins in the histogram should be num_bins^3

    E.g. hists[0,9,5] contains the number of image_color pixels such that:
      - their R values fall in bin 0
      - their G values fall in bin 9
      - their B values fall in bin 5
    '''
    
    
    #print("img_color_doube INT", list(map(int,img_color_double)))
    
    img_color_double = np.reshape(img_color_double, (16384,3))
    img_color_double = list(map(divide255, img_color_double))
    
    
    bins = np.arange(0,1,1/num_bins)
    if bins[len(bins)-1] != 1:
        bins = np.append(bins,1)
    
    hists = np.zeros(shape=(num_bins, num_bins, num_bins))
    for x in img_color_double:
        hists[chooseBin(bins,x[0])][chooseBin(bins,x[1])][chooseBin(bins,x[2])] += 1
    hists = np.reshape(hists,-1)
    total = sum(hists)
    hists = np.array(list(map(lambda x: x/total, hists)))
    return hists

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
# Compose and test RGB histograms (rgb_hist)
plt.figure(2)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_color = 5

plt.subplot(1,2,2)
print("img_color: ", img_color)
hist_rgb1 = rgb_hist(img_color.astype('double'), num_bins_color)
plt.bar(np.array(range(1, hist_rgb1.size+1)),hist_rgb1)
# Out:
# img_color:  [[[53 51 32]
#   [53 51 10]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]
#
#  [[25 25 25]
#   [25 25 25]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]
#
#  [[25 25 25]
#   [25 25 25]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]
#
#  ...
#
#  [[25 25 25]
#   [25 25 25]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]
#
#  [[25 25 25]
#   [25 25 25]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]
#
#  [[25 25 25]
#   [25 25 25]
#   [25 25 25]
#   ...
#   [25 25 25]
#   [25 25 25]
#   [25 25 25]]]
# <BarContainer object of 125 artists>

# %% [markdown]
# ##### RG

# %%
def rg_hist(img_color_double, num_bins = 5, show_verbose = False):
    '''
    Compute the *joint* histogram for the R and G color channels in the image
    The histogram should be normalized so that sum of all values equals 1
    Assume that values in each channel vary between 0 and 255

    img_color - input color image
    num_bins - number of bins used to discretize each channel, total number of bins in the histogram should be num_bins^2

    E.g. hists[0,9] contains the number of image_color pixels such that:
    - their R values fall in bin 0
    - their G values fall in bin 9
    '''


    img_color_double = np.reshape(img_color_double, (16384,3))
    img_color_double = list(map(divide255, img_color_double))
    
    bins = np.arange(0,1,1/num_bins)
    if bins[len(bins)-1] != 1:
        bins = np.append(bins,1)
    
    hists = np.zeros(shape=(num_bins, num_bins))
    for x in img_color_double:
        hists[chooseBin(bins,x[0])][chooseBin(bins,x[1])] += 1
    hists = np.reshape(hists,-1)
    total = sum(hists)
    hists = np.array(list(map(lambda x: x/total, hists)))
    return hists

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
#Compose and test RG histograms (histogram_module.rg_hist)
plt.figure(3)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_color = 5
plt.subplot(1,2,2)
hist_rg = rg_hist(img_color.astype('double'), num_bins_color)
plt.bar(np.array(range(1,hist_rg.size+1)),hist_rg)
plt.show()

# %% [markdown]
# ##### DXDY

# %%
def gaussderiv(img, sigma):

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
#   x = np.array([[ -3, 3]])
  x = np.array([[-1, 0, 1],[-1, 0, 1],[-1, 0, 1]])
  y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]])
  imgDx = conv2(img, x)
  imgDy = conv2(img, y)
#   plt.figure()
#   plt.imshow(imgDx)
#   plt.figure()
#   plt.imshow(imgDy)
#   plt.show()
  return imgDx, imgDy

# %%
def dxdy_hist(img_gray, num_bins = 5, show_verbose = False):
  '''
  Compute the *joint* histogram of Gaussian partial derivatives of the image in x and y direction
  Set sigma to 3.0 and cap the range of derivative values is in the range [-6, 6]
  The histogram should be normalized so that sum of all values equals 1

  img_gray - input gray value image
  num_bins - number of bins used to discretize each dimension, total number of bins in the histogram should be num_bins^2

  Note: you can use the function gaussderiv from the Filtering exercise
  '''
  
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  imgDx, imgDy = gaussderiv(img_gray, 3.0)
  x = np.reshape(imgDx, imgDx.size)
  y = np.reshape(imgDy, imgDy.size)
  hists1, _ = np.histogram(x, bins=num_bins, range=(0,255), density=True)
  hists2, _ = np.histogram(y, bins=num_bins, range=(0,255), density=True)
  hists = np.concatenate((hists1, hists2))
  return hists

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
#Compose and test dxdy histograms (histogram_module.dxdy_hist)

plt.figure(5)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_dxdy = 10
plt.subplot(1,2,2)
hist_dxdy = dxdy_hist(img_gray, num_bins_dxdy)
plt.bar(np.array(range(1,hist_dxdy.size+1)),hist_dxdy)
plt.show()

# %% [markdown]
# #### Exercise 2.c **(1 Point)**
# Implement the histogram distance functions.
#
# In more details, implement the function *dist_intersect*:
# \begin{equation}
# \bigcap(Q,V)=1-\frac{1}{2}\left(
# \frac{\sum_i \min(q_i,v_i)}{\sum_i q_i} +
# \frac{\sum_i \min(q_i,v_i)}{\sum_i v_i}
# \right)
# \end{equation}
#
# the *dist_l2* function:
# \begin{equation}
# d(Q,V)=\sqrt{\sum_i (q_i-v_i)^2}
# \end{equation}
#
# and the *dist_chi2*:
# \begin{equation}
# \chi^2(Q,V)=\sum_i \frac{(q_i-v_i)^2}{q_i + v_i}
# \end{equation}

# %%
def dist_intersect(x,y):
    '''
    Compute the intersection distance between histograms x and y
    Return 1 - hist_intersection, so smaller values correspond to more similar histograms
    Check that the distance range in [0,1]
    '''

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    sumMin = 0
    for i in range(len(x)):
        sumMin += min(x[i], y[i])
    hist_intersection = 0.5 * ((sumMin/sum(x)) + (sumMin/sum(y)))
    print("hist_intersection: ", hist_intersection)
    print("hist_return_value: ", 1 - hist_intersection)
    return 1 - hist_intersection


def dist_l2(x,y):
  '''
  Compute the L2 distance between x and y histograms
  Check that the distance range in [0,sqrt(2)]
  '''
    
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  l2_dist = np.sqrt(np.sum((x - y) ** 2))
  assert 0 <= l2_dist <= np.sqrt(2)
  return l2_dist


def dist_chi2(x,y):
  '''
  Compute chi2 distance between x and y
  Check that the distance range in [0,Inf]
  Add a minimum score to each cell of the histograms (e.g. 1) to avoid division by 0
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  x[x==0] = 0.000001
  chi2_dist = np.sum((np.power((x - y), 2))/(x + y))
  assert 0 <= chi2_dist <= np.inf
  return chi2_dist

# %% [markdown]
# ## Question 3: Object Identification **(11 Points)**

# %% [markdown]
# ### Exercise 3 - Code **(7 Points)**

# %% [markdown]
# #### Exercise 3.a **(4 Points)**
# Having implemented different distance functions and image histograms, you can now test how suitable
# they are for retrieving images in query-by-example scenario. Implement a function find_best_match which takes a list of model images and a list of query images and for each query im-
# age returns the index of closest model image. The function should take string parameters, which identify
# distance function, histogram function and number of histogram bins. See comments in the beginning of
# find_best_match function for more details. Additionally to the indices of the best matching images your implemen-
# tation should also return a matrix which contains distances between all pairs of model and query images.
# (3 points)

# %%
def is_grayvalue_hist(hist_name):
  '''
  Handle function to discriminate when your input 
  function is in gray_scale or colors.
  '''
  if hist_name == 'grayvalue' or hist_name == 'dxdy':
    return True
  elif hist_name == 'rgb' or hist_name == 'rg':
    return False
  else:
    assert False, 'unknown histogram type'


def get_hist_by_name(img, num_bins_gray, hist_name):
  '''
  Handle function to get the correct historgam function 
  by his name.
  '''
  if hist_name == 'grayvalue':
    return normalized_hist(img, num_bins_gray)
  elif hist_name == 'rgb':
    aux = rgb_hist(img, num_bins_gray)
    return aux
  elif hist_name == 'rg':
    return rg_hist(img, num_bins_gray)
  elif hist_name == 'dxdy':
    return dxdy_hist(img, num_bins_gray)
  else:
    assert False, 'unknown hist type: %s'%hist_name


def get_dist_by_name(x, y, dist_name):
  '''
  Handle function to get the correct distance function 
  by his name.
  '''
  if dist_name == 'chi2':
    return dist_chi2(x,y)
  elif dist_name == 'intersect':
    return dist_intersect(x,y)
  elif dist_name == 'l2':
    return dist_l2(x,y)
  elif dist_name == 'all':
    pass
  else:
    assert False, 'unknown distance: %s'%dist_name

def read_files():
  '''
  Handle function to read query and model files
  '''
  with open('model.txt') as fp:
    model_images = fp.readlines()
  model_images = [x.strip() for x in model_images]

  with open('query.txt') as fp:
    query_images = fp.readlines()
  query_images = [x.strip() for x in query_images]

  return query_images, model_images

# %%
# note: use functions 'get_dist_by_name', 'get_hist_by_name' and 'is_grayvalue_hist' to obtain 
#       handles to distance and histogram functions, and to find out whether histogram function 
#       expects grayvalue or color image

def compute_histograms(image_list, hist_type, hist_isgray, num_bins):
  '''
  this function returns a list containing the histograms for
  the list of images given as input.
  '''
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  image_hist = []
  for img in image_list:
    image_hist.append(get_hist_by_name(img, num_bins, hist_type))
  return image_hist



def find_best_match(model_images, query_images, dist_type, hist_type, num_bins):
  '''
  Function to find the best match for each image in the 
  query folder.
  Input:
    model_images: list of strings with the path of model images.
    query_images: list of strings with the path of query images.
    dist_type:    a string to represent the name of the distance you want to 
                  use. Should be one among "l2", "intersect", "chi2".
    hist_type:    a string to represent the name of the histogram you want to 
                  use. Should be one among "grayvalue", "rgb", "rg", "dxdy".
  
  Output:
    best_match:   list containing in each position the index of the retrieved
                  best matching image.
    D:            Matrix with |model_images| rows and |query_images| columns
                  containing the scores of each matching.
  '''
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  model_image_list = []
  for i in model_images:
    img = Image.open(i)
    img = np.array(img).astype('double')
    model_image_list.append(img)
  model_image_hists = compute_histograms(model_image_list, hist_type, False, num_bins)

  query_image_list = []
  for i in query_images:
    img = Image.open(i)
    img = np.array(img).astype('double')
    query_image_list.append(img)
  query_image_hists = compute_histograms(query_image_list, hist_type, False, num_bins)

  best_match = []
  D = []
  for q in range(len(query_image_hists)):
    min = np.inf
    idx = -1
    l = []
    for m in range(len(model_image_hists)):
        d = get_dist_by_name(model_image_hists[q], model_image_hists[m], dist_type)
        l.append(d)
        if (d < min): 
            min = d
            idx = m
    best_match.append(idx)
    D.append(l)
  D = np.array(D)
  D = np.transpose(D)
  best_match = np.array(best_match)
  return best_match, D

# %%
# note: use functions 'get_dist_by_name', 'get_hist_by_name' and 'is_grayvalue_hist' to obtain 
#       handles to distance and histogram functions, and to find out whether histogram function 
#       expects grayvalue or color image

def compute_histograms(image_list, hist_type, hist_isgray, num_bins):
    '''
    this function returns a list containing the histograms for
    the list of images given as input.
    '''
    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    #print("WE ARE INSIDE compute_histograms")
    #print("    image_list: ", image_list)
    #print("    hist_type: ", hist_type)
    #print("    hist_isgray: ", hist_isgray)
    #print("    num_bins: ", num_bins)
    
    image_hist = []
    for img in image_list:
        image_hist.append(get_hist_by_name(img, num_bins, hist_type))
    #print("Hist result:", image_hist)
    return image_hist



def find_best_match(model_images, query_images, dist_type, hist_type, num_bins):
    '''
    Function to find the best match for each image in the 
    query folder.
    Input:
    model_images: list of strings with the path of model images.
    query_images: list of strings with the path of query images.
    dist_type:    a string to represent the name of the distance you want to 
                  use. Should be one among "l2", "intersect", "chi2".
    hist_type:    a string to represent the name of the histogram you want to 
                  use. Should be one among "grayvalue", "rgb", "rg", "dxdy".

    Output:
    best_match:   list containing in each position the index of the retrieved
                  best matching image.
    D:            Matrix with |model_images| rows and |query_images| columns
                  containing the scores of each matching.
    '''
    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    
    model_image_list = []
    for i in model_images:
        img = Image.open(i)
        img = np.array(img).astype('double')
        model_image_list.append(img)

    query_image_list = []
    for i in query_images:
        img = Image.open(i)
        img = np.array(img).astype('double')
        query_image_list.append(img)
    
    model_image_hists = compute_histograms(model_image_list, hist_type, is_grayvalue_hist(hist_type), num_bins)
    query_image_hists = compute_histograms(query_image_list, hist_type, is_grayvalue_hist(hist_type), num_bins)
    #print("model_image_hists: ", model_image_hists[0])
    #print("query_image_hists: ", query_image_hists[0])
    #print("equal? ", np.array_equal(model_image_hists[0], query_image_hists[0])
        
    best_match = np.zeros(len(query_image_hists),dtype=int)
    #best_match = []
    
    for x in range(len(query_image_hists)):
        #print("$$$$$$$$$$$$$$$$$$$$$$$$$$$")
        inx = -1
        minimumD = np.inf
        #print("ITER NUMBER: " + str(x))
        for y in range(len(model_image_hists)):
            aux = get_dist_by_name(query_image_hists[x], model_image_hists[y], dist_type)
            #print("In model image iter number " + str(y) + " dist is " + str(aux))
            if(aux < minimumD):
                minimumD = aux
                inx = y
        #best_match.append(inx)
        #print("------------------------------------------")
        #print("for query image " + str(x) + ", best match is: " + str(inx))
        best_match[x] = inx
        #print("this is the new modified best_match array: ", best_match)
        #print("------------------------------------------\n")
        #print("$$$$$$$$$$$$$$$$$$$$$$$$$$$\n\n")
          
    D = []
    #print("best_match: ", best_match)
    best_match = np.array(best_match)
    return best_match, D

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
# model_images - list of file names of model images
# query_images - list of file names of query images

query_images, model_images = read_files()

dist_type = 'intersect'
hist_type = 'rgb'
num_bins = 10

[best_match, D] = find_best_match(
    model_images, query_images, dist_type, hist_type, num_bins)

print("Indexes of correct retrieved images is:\n ", *np.where(best_match == np.arange(len(query_images))))
print("The Recognition rate is", sum(best_match == np.arange(len(query_images)))/len(query_images))
# Out:
# hist_intersection:  0.8853759765625
# hist_return_value:  0.1146240234375
# hist_intersection:  0.1571044921875
# hist_return_value:  0.8428955078125
# hist_intersection:  0.6785888671875
# hist_return_value:  0.3214111328125
# hist_intersection:  0.6009521484375
# hist_return_value:  0.3990478515625
# hist_intersection:  0.12054443359375
# hist_return_value:  0.87945556640625
# hist_intersection:  0.0562744140625
# hist_return_value:  0.9437255859375
# hist_intersection:  0.4881591796875
# hist_return_value:  0.5118408203125
# hist_intersection:  0.7100830078125
# hist_return_value:  0.2899169921875
# hist_intersection:  0.31268310546875
# hist_return_value:  0.68731689453125
# hist_intersection:  0.59332275390625
# hist_return_value:  0.40667724609375
# hist_intersection:  0.1533203125
# hist_return_value:  0.8466796875
# hist_intersection:  0.742431640625
# hist_return_value:  0.257568359375
# hist_intersection:  0.5408935546875
# hist_return_value:  0.4591064453125
# hist_intersection:  0.1837158203125
# hist_return_value:  0.8162841796875
# hist_intersection:  0.11175537109375
# hist_return_value:  0.88824462890625
# hist_intersection:  0.57403564453125
# hist_return_value:  0.42596435546875
# hist_intersection:  0.73419189453125
# hist_return_value:  0.26580810546875
# hist_intersection:  0.6942138671875
# hist_return_value:  0.3057861328125
# hist_intersection:  0.15899658203125
# hist_return_value:  0.84100341796875
# hist_intersection:  0.1192626953125
# hist_return_value:  0.8807373046875
# hist_intersection:  0.67901611328125
# hist_return_value:  0.32098388671875
# hist_intersection:  0.062255859375
# hist_return_value:  0.937744140625
# hist_intersection:  0.34600830078125
# hist_return_value:  0.65399169921875
# hist_intersection:  0.5079345703125
# hist_return_value:  0.4920654296875
# hist_intersection:  0.65325927734375
# hist_return_value:  0.34674072265625
# hist_intersection:  0.47198486328125
# hist_return_value:  0.52801513671875
# hist_intersection:  0.35595703125
# hist_return_value:  0.64404296875
# hist_intersection:  0.72784423828125
# hist_return_value:  0.27215576171875
# hist_intersection:  0.44268798828125
# hist_return_value:  0.55731201171875
# hist_intersection:  0.68695068359375
# hist_return_value:  0.31304931640625
# hist_intersection:  0.537109375
# hist_return_value:  0.462890625
# hist_intersection:  0.47930908203125
# hist_return_value:  0.52069091796875
# hist_intersection:  0.1744384765625
# hist_return_value:  0.8255615234375
# hist_intersection:  0.26190185546875
# hist_return_value:  0.73809814453125
# hist_intersection:  0.62713623046875
# hist_return_value:  0.37286376953125
# hist_intersection:  0.311767578125
# hist_return_value:  0.688232421875
# hist_intersection:  0.09393310546875
# hist_return_value:  0.90606689453125
# hist_intersection:  0.11163330078125
# hist_return_value:  0.88836669921875
# hist_intersection:  0.3564453125
# hist_return_value:  0.6435546875
# hist_intersection:  0.11651611328125
# hist_return_value:  0.88348388671875
# hist_intersection:  0.1983642578125
# hist_return_value:  0.8016357421875
# hist_intersection:  0.63922119140625
# hist_return_value:  0.36077880859375
# hist_intersection:  0.62109375
# hist_return_value:  0.37890625
# hist_intersection:  0.2275390625
# hist_return_value:  0.7724609375
# hist_intersection:  0.58758544921875
# hist_return_value:  0.41241455078125
# hist_intersection:  0.086669921875
# hist_return_value:  0.913330078125
# hist_intersection:  0.08184814453125
# hist_return_value:  0.91815185546875
# hist_intersection:  0.099365234375
# hist_return_value:  0.900634765625
# hist_intersection:  0.61322021484375
# hist_return_value:  0.38677978515625
# hist_intersection:  0.14923095703125
# hist_return_value:  0.85076904296875
# hist_intersection:  0.391357421875
# hist_return_value:  0.608642578125
# hist_intersection:  0.10052490234375
# hist_return_value:  0.89947509765625
# hist_intersection:  0.127197265625
# hist_return_value:  0.872802734375
# hist_intersection:  0.40997314453125
# hist_return_value:  0.59002685546875
# hist_intersection:  0.1844482421875
# hist_return_value:  0.8155517578125
# hist_intersection:  0.4376220703125
# hist_return_value:  0.5623779296875
# hist_intersection:  0.15191650390625
# hist_return_value:  0.84808349609375
# hist_intersection:  0.6954345703125
# hist_return_value:  0.3045654296875
# hist_intersection:  0.67791748046875
# hist_return_value:  0.32208251953125
# hist_intersection:  0.59136962890625
# hist_return_value:  0.40863037109375
# hist_intersection:  0.26092529296875
# hist_return_value:  0.73907470703125
# hist_intersection:  0.58221435546875
# hist_return_value:  0.41778564453125
# hist_intersection:  0.07122802734375
# hist_return_value:  0.92877197265625
# hist_intersection:  0.175048828125
# hist_return_value:  0.824951171875
# hist_intersection:  0.05364990234375
# hist_return_value:  0.94635009765625
# hist_intersection:  0.10400390625
# hist_return_value:  0.89599609375
# hist_intersection:  0.72564697265625
# hist_return_value:  0.27435302734375
# hist_intersection:  0.13995361328125
# hist_return_value:  0.86004638671875
# hist_intersection:  0.6861572265625
# hist_return_value:  0.3138427734375
# hist_intersection:  0.404296875
# hist_return_value:  0.595703125
# hist_intersection:  0.07171630859375
# hist_return_value:  0.92828369140625
# hist_intersection:  0.12060546875
# hist_return_value:  0.87939453125
# hist_intersection:  0.657470703125
# hist_return_value:  0.342529296875
# hist_intersection:  0.11016845703125
# hist_return_value:  0.88983154296875
# hist_intersection:  0.49322509765625
# hist_return_value:  0.50677490234375
# hist_intersection:  0.42559814453125
# hist_return_value:  0.57440185546875
# hist_intersection:  0.59417724609375
# hist_return_value:  0.40582275390625
# hist_intersection:  0.38897705078125
# hist_return_value:  0.61102294921875
# hist_intersection:  0.54541015625
# hist_return_value:  0.45458984375
# hist_intersection:  0.41571044921875
# hist_return_value:  0.58428955078125
# hist_intersection:  0.70977783203125
# hist_return_value:  0.29022216796875
# hist_intersection:  0.6112060546875
# hist_return_value:  0.3887939453125
# hist_intersection:  0.686279296875
# hist_return_value:  0.313720703125
# hist_intersection:  0.56768798828125
# hist_return_value:  0.43231201171875
# hist_intersection:  0.2196044921875
# hist_return_value:  0.7803955078125
# hist_intersection:  0.05615234375
# hist_return_value:  0.94384765625
# hist_intersection:  0.15814208984375
# hist_return_value:  0.84185791015625
# hist_intersection:  0.05224609375
# hist_return_value:  0.94775390625
# hist_intersection:  0.071044921875
# hist_return_value:  0.928955078125
# hist_intersection:  0.1376953125
# hist_return_value:  0.8623046875
# hist_intersection:  0.8671875
# hist_return_value:  0.1328125
# hist_intersection:  0.05438232421875
# hist_return_value:  0.94561767578125
# hist_intersection:  0.0904541015625
# hist_return_value:  0.9095458984375
# hist_intersection:  0.4111328125
# hist_return_value:  0.5888671875
# hist_intersection:  0.4925537109375
# hist_return_value:  0.5074462890625
# hist_intersection:  0.416259765625
# hist_return_value:  0.583740234375
# hist_intersection:  0.0806884765625
# hist_return_value:  0.9193115234375
# hist_intersection:  0.51043701171875
# hist_return_value:  0.48956298828125
# hist_intersection:  0.09478759765625
# hist_return_value:  0.90521240234375
# hist_intersection:  0.71832275390625
# hist_return_value:  0.28167724609375
# hist_intersection:  0.11871337890625
# hist_return_value:  0.88128662109375
# hist_intersection:  0.1103515625
# hist_return_value:  0.8896484375
# hist_intersection:  0.15606689453125
# hist_return_value:  0.84393310546875
# hist_intersection:  0.40106201171875
# hist_return_value:  0.59893798828125
# hist_intersection:  0.40203857421875
# hist_return_value:  0.59796142578125
# hist_intersection:  0.10919189453125
# hist_return_value:  0.89080810546875
# hist_intersection:  0.2027587890625
# hist_return_value:  0.7972412109375
# hist_intersection:  0.239990234375
# hist_return_value:  0.760009765625
# hist_intersection:  0.456787109375
# hist_return_value:  0.543212890625
# hist_intersection:  0.1112060546875
# hist_return_value:  0.8887939453125
# hist_intersection:  0.3807373046875
# hist_return_value:  0.6192626953125
# hist_intersection:  0.3590087890625
# hist_return_value:  0.6409912109375
# hist_intersection:  0.2205810546875
# hist_return_value:  0.7794189453125
# hist_intersection:  0.0504150390625
# hist_return_value:  0.9495849609375
# hist_intersection:  0.31170654296875
# hist_return_value:  0.68829345703125
# hist_intersection:  0.36236572265625
# hist_return_value:  0.63763427734375
# hist_intersection:  0.30865478515625
# hist_return_value:  0.69134521484375
# hist_intersection:  0.078125
# hist_return_value:  0.921875
# hist_intersection:  0.2528076171875
# hist_return_value:  0.7471923828125
# hist_intersection:  0.06103515625
# hist_return_value:  0.93896484375
# hist_intersection:  0.50933837890625
# hist_return_value:  0.49066162109375
# hist_intersection:  0.410888671875
# hist_return_value:  0.589111328125
# hist_intersection:  0.34112548828125
# hist_return_value:  0.65887451171875
# hist_intersection:  0.179931640625
# hist_return_value:  0.820068359375
# hist_intersection:  0.35113525390625
# hist_return_value:  0.64886474609375
# hist_intersection:  0.37066650390625
# hist_return_value:  0.62933349609375
# hist_intersection:  0.37249755859375
# hist_return_value:  0.62750244140625
# hist_intersection:  0.20294189453125
# hist_return_value:  0.79705810546875
# hist_intersection:  0.4180908203125
# hist_return_value:  0.5819091796875
# hist_intersection:  0.70574951171875
# hist_return_value:  0.29425048828125
# hist_intersection:  0.30792236328125
# hist_return_value:  0.69207763671875
# hist_intersection:  0.068115234375
# hist_return_value:  0.931884765625
# hist_intersection:  0.759521484375
# hist_return_value:  0.240478515625
# hist_intersection:  0.28948974609375
# hist_return_value:  0.71051025390625
# hist_intersection:  0.57733154296875
# hist_return_value:  0.42266845703125
# hist_intersection:  0.578125
# hist_return_value:  0.421875
# hist_intersection:  0.4005126953125
# hist_return_value:  0.5994873046875
# hist_intersection:  0.1571044921875
# hist_return_value:  0.8428955078125
# hist_intersection:  0.4322509765625
# hist_return_value:  0.5677490234375
# hist_intersection:  0.12127685546875
# hist_return_value:  0.87872314453125
# hist_intersection:  0.6265869140625
# hist_return_value:  0.3734130859375
# hist_intersection:  0.42816162109375
# hist_return_value:  0.57183837890625
# hist_intersection:  0.43084716796875
# hist_return_value:  0.56915283203125
# hist_intersection:  0.5140380859375
# hist_return_value:  0.4859619140625
# hist_intersection:  0.12469482421875
# hist_return_value:  0.87530517578125
# hist_intersection:  0.5213623046875
# hist_return_value:  0.4786376953125
# hist_intersection:  0.098876953125
# hist_return_value:  0.901123046875
# hist_intersection:  0.2855224609375
# hist_return_value:  0.7144775390625
# hist_intersection:  0.22100830078125
# hist_return_value:  0.77899169921875
# hist_intersection:  0.2252197265625
# hist_return_value:  0.7747802734375
# hist_intersection:  0.320068359375
# hist_return_value:  0.679931640625
# hist_intersection:  0.4862060546875
# hist_return_value:  0.5137939453125
# hist_intersection:  0.58148193359375
# hist_return_value:  0.41851806640625
# hist_intersection:  0.51751708984375
# hist_return_value:  0.48248291015625
# hist_intersection:  0.6275634765625
# hist_return_value:  0.3724365234375
# hist_intersection:  0.2161865234375
# hist_return_value:  0.7838134765625
# hist_intersection:  0.4254150390625
# hist_return_value:  0.5745849609375
# hist_intersection:  0.11749267578125
# hist_return_value:  0.88250732421875
# hist_intersection:  0.446533203125
# hist_return_value:  0.553466796875
# hist_intersection:  0.1956787109375
# hist_return_value:  0.8043212890625
# hist_intersection:  0.3131103515625
# hist_return_value:  0.6868896484375
# hist_intersection:  0.06036376953125
# hist_return_value:  0.93963623046875
# hist_intersection:  0.68792724609375
# hist_return_value:  0.31207275390625
# hist_intersection:  0.120849609375
# hist_return_value:  0.879150390625
# hist_intersection:  0.38018798828125
# hist_return_value:  0.61981201171875
# hist_intersection:  0.07635498046875
# hist_return_value:  0.92364501953125
# hist_intersection:  0.54852294921875
# hist_return_value:  0.45147705078125
# hist_intersection:  0.23797607421875
# hist_return_value:  0.76202392578125
# hist_intersection:  0.4302978515625
# hist_return_value:  0.5697021484375
# hist_intersection:  0.091796875
# hist_return_value:  0.908203125
# hist_intersection:  0.26239013671875
# hist_return_value:  0.73760986328125
# hist_intersection:  0.227294921875
# hist_return_value:  0.772705078125
# hist_intersection:  0.0389404296875
# hist_return_value:  0.9610595703125
# hist_intersection:  0.287841796875
# hist_return_value:  0.712158203125
# hist_intersection:  0.50140380859375
# hist_return_value:  0.49859619140625
# hist_intersection:  0.77496337890625
# hist_return_value:  0.22503662109375
# hist_intersection:  0.37451171875
# hist_return_value:  0.62548828125
# hist_intersection:  0.4171142578125
# hist_return_value:  0.5828857421875
# hist_intersection:  0.7100830078125
# hist_return_value:  0.2899169921875
# hist_intersection:  0.14959716796875
# hist_return_value:  0.85040283203125
# hist_intersection:  0.84637451171875
# hist_return_value:  0.15362548828125
# hist_intersection:  0.60430908203125
# hist_return_value:  0.39569091796875
# hist_intersection:  0.15350341796875
# hist_return_value:  0.84649658203125
# hist_intersection:  0.06878662109375
# hist_return_value:  0.93121337890625
# hist_intersection:  0.4703369140625
# hist_return_value:  0.5296630859375
# hist_intersection:  0.7286376953125
# hist_return_value:  0.2713623046875
# hist_intersection:  0.3111572265625
# hist_return_value:  0.6888427734375
# hist_intersection:  0.68206787109375
# hist_return_value:  0.31793212890625
# hist_intersection:  0.16485595703125
# hist_return_value:  0.83514404296875
# hist_intersection:  0.662841796875
# hist_return_value:  0.337158203125
# hist_intersection:  0.50433349609375
# hist_return_value:  0.49566650390625
# hist_intersection:  0.28302001953125
# hist_return_value:  0.71697998046875
# hist_intersection:  0.11358642578125
# hist_return_value:  0.88641357421875
# hist_intersection:  0.5672607421875
# hist_return_value:  0.4327392578125
# hist_intersection:  0.66387939453125
# hist_return_value:  0.33612060546875
# hist_intersection:  0.6268310546875
# hist_return_value:  0.3731689453125
# hist_intersection:  0.1435546875
# hist_return_value:  0.8564453125
# hist_intersection:  0.15924072265625
# hist_return_value:  0.84075927734375
# hist_intersection:  0.66888427734375
# hist_return_value:  0.33111572265625
# hist_intersection:  0.07666015625
# hist_return_value:  0.92333984375
# hist_intersection:  0.3839111328125
# hist_return_value:  0.6160888671875
# hist_intersection:  0.50262451171875
# hist_return_value:  0.49737548828125
# hist_intersection:  0.73724365234375
# hist_return_value:  0.26275634765625
# hist_intersection:  0.440185546875
# hist_return_value:  0.559814453125
# hist_intersection:  0.35833740234375
# hist_return_value:  0.64166259765625
# hist_intersection:  0.6943359375
# hist_return_value:  0.3056640625
# hist_intersection:  0.45751953125
# hist_return_value:  0.54248046875
# hist_intersection:  0.674560546875
# hist_return_value:  0.325439453125
# hist_intersection:  0.53363037109375
# hist_return_value:  0.46636962890625
# hist_intersection:  0.4833984375
# hist_return_value:  0.5166015625
# hist_intersection:  0.12481689453125
# hist_return_value:  0.87518310546875
# hist_intersection:  0.1534423828125
# hist_return_value:  0.8465576171875
# hist_intersection:  0.63665771484375
# hist_return_value:  0.36334228515625
# hist_intersection:  0.1798095703125
# hist_return_value:  0.8201904296875
# hist_intersection:  0.10797119140625
# hist_return_value:  0.89202880859375
# hist_intersection:  0.11614990234375
# hist_return_value:  0.88385009765625
# hist_intersection:  0.28289794921875
# hist_return_value:  0.71710205078125
# hist_intersection:  0.124755859375
# hist_return_value:  0.875244140625
# hist_intersection:  0.1646728515625
# hist_return_value:  0.8353271484375
# hist_intersection:  0.5855712890625
# hist_return_value:  0.4144287109375
# hist_intersection:  0.5611572265625
# hist_return_value:  0.4388427734375
# hist_intersection:  0.22650146484375
# hist_return_value:  0.77349853515625
# hist_intersection:  0.5972900390625
# hist_return_value:  0.4027099609375
# hist_intersection:  0.10540771484375
# hist_return_value:  0.89459228515625
# hist_intersection:  0.130126953125
# hist_return_value:  0.869873046875
# hist_intersection:  0.12371826171875
# hist_return_value:  0.87628173828125
# hist_intersection:  0.500732421875
# hist_return_value:  0.499267578125
# hist_intersection:  0.1466064453125
# hist_return_value:  0.8533935546875
# hist_intersection:  0.525146484375
# hist_return_value:  0.474853515625
# hist_intersection:  0.1182861328125
# hist_return_value:  0.8817138671875
# hist_intersection:  0.1129150390625
# hist_return_value:  0.8870849609375
# hist_intersection:  0.43231201171875
# hist_return_value:  0.56768798828125
# hist_intersection:  0.19720458984375
# hist_return_value:  0.80279541015625
# hist_intersection:  0.38623046875
# hist_return_value:  0.61376953125
# hist_intersection:  0.1796875
# hist_return_value:  0.8203125
# hist_intersection:  0.75482177734375
# hist_return_value:  0.24517822265625
# hist_intersection:  0.607421875
# hist_return_value:  0.392578125
# hist_intersection:  0.522216796875
# hist_return_value:  0.477783203125
# hist_intersection:  0.18682861328125
# hist_return_value:  0.81317138671875
# hist_intersection:  0.5850830078125
# hist_return_value:  0.4149169921875
# hist_intersection:  0.0804443359375
# hist_return_value:  0.9195556640625
# hist_intersection:  0.18206787109375
# hist_return_value:  0.81793212890625
# hist_intersection:  0.0604248046875
# hist_return_value:  0.9395751953125
# hist_intersection:  0.1123046875
# hist_return_value:  0.8876953125
# hist_intersection:  0.69549560546875
# hist_return_value:  0.30450439453125
# hist_intersection:  0.1622314453125
# hist_return_value:  0.8377685546875
# hist_intersection:  0.73980712890625
# hist_return_value:  0.26019287109375
# hist_intersection:  0.40020751953125
# hist_return_value:  0.59979248046875
# hist_intersection:  0.1143798828125
# hist_return_value:  0.8856201171875
# hist_intersection:  0.26837158203125
# hist_return_value:  0.73162841796875
# hist_intersection:  0.7825927734375
# hist_return_value:  0.2174072265625
# hist_intersection:  0.1212158203125
# hist_return_value:  0.8787841796875
# hist_intersection:  0.4849853515625
# hist_return_value:  0.5150146484375
# hist_intersection:  0.422119140625
# hist_return_value:  0.577880859375
# hist_intersection:  0.5947265625
# hist_return_value:  0.4052734375
# hist_intersection:  0.40057373046875
# hist_return_value:  0.59942626953125
# hist_intersection:  0.47906494140625
# hist_return_value:  0.52093505859375
# hist_intersection:  0.44775390625
# hist_return_value:  0.55224609375
# hist_intersection:  0.75360107421875
# hist_return_value:  0.24639892578125
# hist_intersection:  0.63848876953125
# hist_return_value:  0.36151123046875
# hist_intersection:  0.52728271484375
# hist_return_value:  0.47271728515625
# hist_intersection:  0.5650634765625
# hist_return_value:  0.4349365234375
# hist_intersection:  0.155517578125
# hist_return_value:  0.844482421875
# hist_intersection:  0.06719970703125
# hist_return_value:  0.93280029296875
# hist_intersection:  0.17156982421875
# hist_return_value:  0.82843017578125
# hist_intersection:  0.07672119140625
# hist_return_value:  0.92327880859375
# hist_intersection:  0.210693359375
# hist_return_value:  0.789306640625
# hist_intersection:  0.5234375
# hist_return_value:  0.4765625
# hist_intersection:  0.1220703125
# hist_return_value:  0.8779296875
# hist_intersection:  0.48883056640625
# hist_return_value:  0.51116943359375
# hist_intersection:  0.9034423828125
# hist_return_value:  0.0965576171875
# hist_intersection:  0.29412841796875
# hist_return_value:  0.70587158203125
# hist_intersection:  0.04150390625
# hist_return_value:  0.95849609375
# hist_intersection:  0.48907470703125
# hist_return_value:  0.51092529296875
# hist_intersection:  0.533935546875
# hist_return_value:  0.466064453125
# hist_intersection:  0.32513427734375
# hist_return_value:  0.67486572265625
# hist_intersection:  0.56884765625
# hist_return_value:  0.43115234375
# hist_intersection:  0.15814208984375
# hist_return_value:  0.84185791015625
# hist_intersection:  0.50091552734375
# hist_return_value:  0.49908447265625
# hist_intersection:  0.58929443359375
# hist_return_value:  0.41070556640625
# hist_intersection:  0.20269775390625
# hist_return_value:  0.79730224609375
# hist_intersection:  0.15521240234375
# hist_return_value:  0.84478759765625
# hist_intersection:  0.49151611328125
# hist_return_value:  0.50848388671875
# hist_intersection:  0.49798583984375
# hist_return_value:  0.50201416015625
# hist_intersection:  0.5269775390625
# hist_return_value:  0.4730224609375
# hist_intersection:  0.30670166015625
# hist_return_value:  0.69329833984375
# hist_intersection:  0.1842041015625
# hist_return_value:  0.8157958984375
# hist_intersection:  0.4952392578125
# hist_return_value:  0.5047607421875
# hist_intersection:  0.04986572265625
# hist_return_value:  0.95013427734375
# hist_intersection:  0.5008544921875
# hist_return_value:  0.4991455078125
# hist_intersection:  0.654296875
# hist_return_value:  0.345703125
# hist_intersection:  0.476806640625
# hist_return_value:  0.523193359375
# hist_intersection:  0.4676513671875
# hist_return_value:  0.5323486328125
# hist_intersection:  0.491943359375
# hist_return_value:  0.508056640625
# hist_intersection:  0.51458740234375
# hist_return_value:  0.48541259765625
# hist_intersection:  0.4453125
# hist_return_value:  0.5546875
# hist_intersection:  0.49920654296875
# hist_return_value:  0.50079345703125
# hist_intersection:  0.48980712890625
# hist_return_value:  0.51019287109375
# hist_intersection:  0.48126220703125
# hist_return_value:  0.51873779296875
# hist_intersection:  0.10455322265625
# hist_return_value:  0.89544677734375
# hist_intersection:  0.20709228515625
# hist_return_value:  0.79290771484375
# hist_intersection:  0.49798583984375
# hist_return_value:  0.50201416015625
# hist_intersection:  0.16119384765625
# hist_return_value:  0.83880615234375
# hist_intersection:  0.1895751953125
# hist_return_value:  0.8104248046875
# hist_intersection:  0.09698486328125
# hist_return_value:  0.90301513671875
# hist_intersection:  0.27667236328125
# hist_return_value:  0.72332763671875
# hist_intersection:  0.1326904296875
# hist_return_value:  0.8673095703125
# hist_intersection:  0.15093994140625
# hist_return_value:  0.84906005859375
# hist_intersection:  0.49578857421875
# hist_return_value:  0.50421142578125
# hist_intersection:  0.47039794921875
# hist_return_value:  0.52960205078125
# hist_intersection:  0.2108154296875
# hist_return_value:  0.7891845703125
# hist_intersection:  0.56353759765625
# hist_return_value:  0.43646240234375
# hist_intersection:  0.10003662109375
# hist_return_value:  0.89996337890625
# hist_intersection:  0.0745849609375
# hist_return_value:  0.9254150390625
# hist_intersection:  0.2437744140625
# hist_return_value:  0.7562255859375
# hist_intersection:  0.472412109375
# hist_return_value:  0.527587890625
# hist_intersection:  0.2218017578125
# hist_return_value:  0.7781982421875
# hist_intersection:  0.39752197265625
# hist_return_value:  0.60247802734375
# hist_intersection:  0.19140625
# hist_return_value:  0.80859375
# hist_intersection:  0.23809814453125
# hist_return_value:  0.76190185546875
# hist_intersection:  0.4068603515625
# hist_return_value:  0.5931396484375
# hist_intersection:  0.2684326171875
# hist_return_value:  0.7315673828125
# hist_intersection:  0.3526611328125
# hist_return_value:  0.6473388671875
# hist_intersection:  0.23663330078125
# hist_return_value:  0.76336669921875
# hist_intersection:  0.5281982421875
# hist_return_value:  0.4718017578125
# hist_intersection:  0.521240234375
# hist_return_value:  0.478759765625
# hist_intersection:  0.5069580078125
# hist_return_value:  0.4930419921875
# hist_intersection:  0.19195556640625
# hist_return_value:  0.80804443359375
# hist_intersection:  0.48907470703125
# hist_return_value:  0.51092529296875
# hist_intersection:  0.05291748046875
# hist_return_value:  0.94708251953125
# hist_intersection:  0.1673583984375
# hist_return_value:  0.8326416015625
# hist_intersection:  0.03887939453125
# hist_return_value:  0.96112060546875
# hist_intersection:  0.09002685546875
# hist_return_value:  0.90997314453125
# hist_intersection:  0.52520751953125
# hist_return_value:  0.47479248046875
# hist_intersection:  0.2452392578125
# hist_return_value:  0.7547607421875
# hist_intersection:  0.52685546875
# hist_return_value:  0.47314453125
# hist_intersection:  0.47021484375
# hist_return_value:  0.52978515625
# hist_intersection:  0.09356689453125
# hist_return_value:  0.90643310546875
# hist_intersection:  0.15960693359375
# hist_return_value:  0.84039306640625
# hist_intersection:  0.50714111328125
# hist_return_value:  0.49285888671875
# hist_intersection:  0.09259033203125
# hist_return_value:  0.90740966796875
# hist_intersection:  0.59771728515625
# hist_return_value:  0.40228271484375
# hist_intersection:  0.3974609375
# hist_return_value:  0.6025390625
# hist_intersection:  0.479248046875
# hist_return_value:  0.520751953125
# hist_intersection:  0.37908935546875
# hist_return_value:  0.62091064453125
# hist_intersection:  0.4656982421875
# hist_return_value:  0.5343017578125
# hist_intersection:  0.40771484375
# hist_return_value:  0.59228515625
# hist_intersection:  0.52838134765625
# hist_return_value:  0.47161865234375
# hist_intersection:  0.51068115234375
# hist_return_value:  0.48931884765625
# hist_intersection:  0.5067138671875
# hist_return_value:  0.4932861328125
# hist_intersection:  0.470947265625
# hist_return_value:  0.529052734375
# hist_intersection:  0.1326904296875
# hist_return_value:  0.8673095703125
# hist_intersection:  0.0406494140625
# hist_return_value:  0.9593505859375
# hist_intersection:  0.150634765625
# hist_return_value:  0.849365234375
# hist_intersection:  0.04290771484375
# hist_return_value:  0.95709228515625
# hist_intersection:  0.1162109375
# hist_return_value:  0.8837890625
# hist_intersection:  0.13848876953125
# hist_return_value:  0.86151123046875
# hist_intersection:  0.40972900390625
# hist_return_value:  0.59027099609375
# hist_intersection:  0.10162353515625
# hist_return_value:  0.89837646484375
# hist_intersection:  0.34857177734375
# hist_return_value:  0.65142822265625
# hist_intersection:  0.6136474609375
# hist_return_value:  0.3863525390625
# hist_intersection:  0.32452392578125
# hist_return_value:  0.67547607421875
# hist_intersection:  0.257080078125
# hist_return_value:  0.742919921875
# hist_intersection:  0.1444091796875
# hist_return_value:  0.8555908203125
# hist_intersection:  0.24566650390625
# hist_return_value:  0.75433349609375
# hist_intersection:  0.18377685546875
# hist_return_value:  0.81622314453125
# hist_intersection:  0.39630126953125
# hist_return_value:  0.60369873046875
# hist_intersection:  0.109375
# hist_return_value:  0.890625
# hist_intersection:  0.26715087890625
# hist_return_value:  0.73284912109375
# hist_intersection:  0.22027587890625
# hist_return_value:  0.77972412109375
# hist_intersection:  0.4754638671875
# hist_return_value:  0.5245361328125
# hist_intersection:  0.1168212890625
# hist_return_value:  0.8831787109375
# hist_intersection:  0.10821533203125
# hist_return_value:  0.89178466796875
# hist_intersection:  0.1405029296875
# hist_return_value:  0.8594970703125
# hist_intersection:  0.36846923828125
# hist_return_value:  0.63153076171875
# hist_intersection:  0.4549560546875
# hist_return_value:  0.5450439453125
# hist_intersection:  0.10650634765625
# hist_return_value:  0.89349365234375
# hist_intersection:  0.33184814453125
# hist_return_value:  0.66815185546875
# hist_intersection:  0.30438232421875
# hist_return_value:  0.69561767578125
# hist_intersection:  0.296630859375
# hist_return_value:  0.703369140625
# hist_intersection:  0.088623046875
# hist_return_value:  0.911376953125
# hist_intersection:  0.13525390625
# hist_return_value:  0.86474609375
# hist_intersection:  0.34625244140625
# hist_return_value:  0.65374755859375
# hist_intersection:  0.1329345703125
# hist_return_value:  0.8670654296875
# hist_intersection:  0.0882568359375
# hist_return_value:  0.9117431640625
# hist_intersection:  0.12286376953125
# hist_return_value:  0.87713623046875
# hist_intersection:  0.099609375
# hist_return_value:  0.900390625
# hist_intersection:  0.19024658203125
# hist_return_value:  0.80975341796875
# hist_intersection:  0.38232421875
# hist_return_value:  0.61767578125
# hist_intersection:  0.1788330078125
# hist_return_value:  0.8211669921875
# hist_intersection:  0.12823486328125
# hist_return_value:  0.87176513671875
# hist_intersection:  0.34796142578125
# hist_return_value:  0.65203857421875
# hist_intersection:  0.5103759765625
# hist_return_value:  0.4896240234375
# hist_intersection:  0.377197265625
# hist_return_value:  0.622802734375
# hist_intersection:  0.2313232421875
# hist_return_value:  0.7686767578125
# hist_intersection:  0.43438720703125
# hist_return_value:  0.56561279296875
# hist_intersection:  0.320068359375
# hist_return_value:  0.679931640625
# hist_intersection:  0.11187744140625
# hist_return_value:  0.88812255859375
# hist_intersection:  0.080322265625
# hist_return_value:  0.919677734375
# hist_intersection:  0.4281005859375
# hist_return_value:  0.5718994140625
# hist_intersection:  0.18994140625
# hist_return_value:  0.81005859375
# hist_intersection:  0.37969970703125
# hist_return_value:  0.62030029296875
# hist_intersection:  0.3623046875
# hist_return_value:  0.6376953125
# hist_intersection:  0.52490234375
# hist_return_value:  0.47509765625
# hist_intersection:  0.16839599609375
# hist_return_value:  0.83160400390625
# hist_intersection:  0.53466796875
# hist_return_value:  0.46533203125
# hist_intersection:  0.17205810546875
# hist_return_value:  0.82794189453125
# hist_intersection:  0.39556884765625
# hist_return_value:  0.60443115234375
# hist_intersection:  0.4932861328125
# hist_return_value:  0.5067138671875
# hist_intersection:  0.23974609375
# hist_return_value:  0.76025390625
# hist_intersection:  0.42474365234375
# hist_return_value:  0.57525634765625
# hist_intersection:  0.1884765625
# hist_return_value:  0.8115234375
# hist_intersection:  0.4969482421875
# hist_return_value:  0.5030517578125
# hist_intersection:  0.14129638671875
# hist_return_value:  0.85870361328125
# hist_intersection:  0.14398193359375
# hist_return_value:  0.85601806640625
# hist_intersection:  0.1170654296875
# hist_return_value:  0.8829345703125
# hist_intersection:  0.24853515625
# hist_return_value:  0.75146484375
# hist_intersection:  0.1092529296875
# hist_return_value:  0.8907470703125
# hist_intersection:  0.1951904296875
# hist_return_value:  0.8048095703125
# hist_intersection:  0.2152099609375
# hist_return_value:  0.7847900390625
# hist_intersection:  0.32476806640625
# hist_return_value:  0.67523193359375
# hist_intersection:  0.3780517578125
# hist_return_value:  0.6219482421875
# hist_intersection:  0.15740966796875
# hist_return_value:  0.84259033203125
# hist_intersection:  0.568359375
# hist_return_value:  0.431640625
# hist_intersection:  0.1444091796875
# hist_return_value:  0.8555908203125
# hist_intersection:  0.39117431640625
# hist_return_value:  0.60882568359375
# hist_intersection:  0.21051025390625
# hist_return_value:  0.78948974609375
# hist_intersection:  0.37298583984375
# hist_return_value:  0.62701416015625
# hist_intersection:  0.1204833984375
# hist_return_value:  0.8795166015625
# hist_intersection:  0.37774658203125
# hist_return_value:  0.62225341796875
# hist_intersection:  0.28564453125
# hist_return_value:  0.71435546875
# hist_intersection:  0.156005859375
# hist_return_value:  0.843994140625
# hist_intersection:  0.08966064453125
# hist_return_value:  0.91033935546875
# hist_intersection:  0.226806640625
# hist_return_value:  0.773193359375
# hist_intersection:  0.11761474609375
# hist_return_value:  0.88238525390625
# hist_intersection:  0.152099609375
# hist_return_value:  0.847900390625
# hist_intersection:  0.14141845703125
# hist_return_value:  0.85858154296875
# hist_intersection:  0.1378173828125
# hist_return_value:  0.8621826171875
# hist_intersection:  0.12225341796875
# hist_return_value:  0.87774658203125
# hist_intersection:  0.08013916015625
# hist_return_value:  0.91986083984375
# hist_intersection:  0.240966796875
# hist_return_value:  0.759033203125
# hist_intersection:  0.32574462890625
# hist_return_value:  0.67425537109375
# hist_intersection:  0.38336181640625
# hist_return_value:  0.61663818359375
# hist_intersection:  0.32989501953125
# hist_return_value:  0.67010498046875
# hist_intersection:  0.3994140625
# hist_return_value:  0.6005859375
# hist_intersection:  0.0577392578125
# hist_return_value:  0.9422607421875
# hist_intersection:  0.5716552734375
# hist_return_value:  0.4283447265625
# hist_intersection:  0.0169677734375
# hist_return_value:  0.9830322265625
# hist_intersection:  0.031982421875
# hist_return_value:  0.968017578125
# hist_intersection:  0.350341796875
# hist_return_value:  0.649658203125
# hist_intersection:  0.79656982421875
# hist_return_value:  0.20343017578125
# hist_intersection:  0.1917724609375
# hist_return_value:  0.8082275390625
# hist_intersection:  0.033203125
# hist_return_value:  0.966796875
# hist_intersection:  0.25537109375
# hist_return_value:  0.74462890625
# hist_intersection:  0.0682373046875
# hist_return_value:  0.9317626953125
# hist_intersection:  0.45404052734375
# hist_return_value:  0.54595947265625
# hist_intersection:  0.04534912109375
# hist_return_value:  0.95465087890625
# hist_intersection:  0.04840087890625
# hist_return_value:  0.95159912109375
# hist_intersection:  0.10009765625
# hist_return_value:  0.89990234375
# hist_intersection:  0.57196044921875
# hist_return_value:  0.42803955078125
# hist_intersection:  0.22491455078125
# hist_return_value:  0.77508544921875
# hist_intersection:  0.0390625
# hist_return_value:  0.9609375
# hist_intersection:  0.0948486328125
# hist_return_value:  0.9051513671875
# hist_intersection:  0.1614990234375
# hist_return_value:  0.8385009765625
# hist_intersection:  0.34197998046875
# hist_return_value:  0.65802001953125
# hist_intersection:  0.03741455078125
# hist_return_value:  0.96258544921875
# hist_intersection:  0.47601318359375
# hist_return_value:  0.52398681640625
# hist_intersection:  0.1678466796875
# hist_return_value:  0.8321533203125
# hist_intersection:  0.08294677734375
# hist_return_value:  0.91705322265625
# hist_intersection:  0.01495361328125
# hist_return_value:  0.98504638671875
# hist_intersection:  0.1085205078125
# hist_return_value:  0.8914794921875
# hist_intersection:  0.1871337890625
# hist_return_value:  0.8128662109375
# hist_intersection:  0.21429443359375
# hist_return_value:  0.78570556640625
# hist_intersection:  0.02618408203125
# hist_return_value:  0.97381591796875
# hist_intersection:  0.20404052734375
# hist_return_value:  0.79595947265625
# hist_intersection:  0.093994140625
# hist_return_value:  0.906005859375
# hist_intersection:  0.26214599609375
# hist_return_value:  0.73785400390625
# hist_intersection:  0.559326171875
# hist_return_value:  0.440673828125
# hist_intersection:  0.185791015625
# hist_return_value:  0.814208984375
# hist_intersection:  0.2027587890625
# hist_return_value:  0.7972412109375
# hist_intersection:  0.2554931640625
# hist_return_value:  0.7445068359375
# hist_intersection:  0.4166259765625
# hist_return_value:  0.5833740234375
# hist_intersection:  0.62689208984375
# hist_return_value:  0.37310791015625
# hist_intersection:  0.10198974609375
# hist_return_value:  0.89801025390625
# hist_intersection:  0.58038330078125
# hist_return_value:  0.41961669921875
# hist_intersection:  0.37689208984375
# hist_return_value:  0.62310791015625
# hist_intersection:  0.16131591796875
# hist_return_value:  0.83868408203125
# hist_intersection:  0.01922607421875
# hist_return_value:  0.98077392578125
# hist_intersection:  0.5030517578125
# hist_return_value:  0.4969482421875
# hist_intersection:  0.1456298828125
# hist_return_value:  0.8543701171875
# hist_intersection:  0.67138671875
# hist_return_value:  0.32861328125
# hist_intersection:  0.66656494140625
# hist_return_value:  0.33343505859375
# hist_intersection:  0.3916015625
# hist_return_value:  0.6083984375
# hist_intersection:  0.074462890625
# hist_return_value:  0.925537109375
# hist_intersection:  0.4625244140625
# hist_return_value:  0.5374755859375
# hist_intersection:  0.04034423828125
# hist_return_value:  0.95965576171875
# hist_intersection:  0.47637939453125
# hist_return_value:  0.52362060546875
# hist_intersection:  0.425537109375
# hist_return_value:  0.574462890625
# hist_intersection:  0.2861328125
# hist_return_value:  0.7138671875
# hist_intersection:  0.30975341796875
# hist_return_value:  0.69024658203125
# hist_intersection:  0.043212890625
# hist_return_value:  0.956787109375
# hist_intersection:  0.376953125
# hist_return_value:  0.623046875
# hist_intersection:  0.04327392578125
# hist_return_value:  0.95672607421875
# hist_intersection:  0.18768310546875
# hist_return_value:  0.81231689453125
# hist_intersection:  0.0994873046875
# hist_return_value:  0.9005126953125
# hist_intersection:  0.14080810546875
# hist_return_value:  0.85919189453125
# hist_intersection:  0.2657470703125
# hist_return_value:  0.7342529296875
# hist_intersection:  0.3896484375
# hist_return_value:  0.6103515625
# hist_intersection:  0.28131103515625
# hist_return_value:  0.71868896484375
# hist_intersection:  0.68316650390625
# hist_return_value:  0.31683349609375
# hist_intersection:  0.68157958984375
# hist_return_value:  0.31842041015625
# hist_intersection:  0.11932373046875
# hist_return_value:  0.88067626953125
# hist_intersection:  0.49908447265625
# hist_return_value:  0.50091552734375
# hist_intersection:  0.0521240234375
# hist_return_value:  0.9478759765625
# hist_intersection:  0.2681884765625
# hist_return_value:  0.7318115234375
# hist_intersection:  0.1571044921875
# hist_return_value:  0.8428955078125
# hist_intersection:  0.260986328125
# hist_return_value:  0.739013671875
# hist_intersection:  0.020263671875
# hist_return_value:  0.979736328125
# hist_intersection:  0.67242431640625
# hist_return_value:  0.32757568359375
# hist_intersection:  0.04595947265625
# hist_return_value:  0.95404052734375
# hist_intersection:  0.30926513671875
# hist_return_value:  0.69073486328125
# hist_intersection:  0.120849609375
# hist_return_value:  0.879150390625
# hist_intersection:  0.282958984375
# hist_return_value:  0.717041015625
# hist_intersection:  0.1412353515625
# hist_return_value:  0.8587646484375
# hist_intersection:  0.27703857421875
# hist_return_value:  0.72296142578125
# hist_intersection:  0.041748046875
# hist_return_value:  0.958251953125
# hist_intersection:  0.22589111328125
# hist_return_value:  0.77410888671875
# hist_intersection:  0.09576416015625
# hist_return_value:  0.90423583984375
# hist_intersection:  0.1002197265625
# hist_return_value:  0.8997802734375
# hist_intersection:  0.16729736328125
# hist_return_value:  0.83270263671875
# hist_intersection:  0.78253173828125
# hist_return_value:  0.21746826171875
# hist_intersection:  0.44989013671875
# hist_return_value:  0.55010986328125
# hist_intersection:  0.56640625
# hist_return_value:  0.43359375
# hist_intersection:  0.546630859375
# hist_return_value:  0.453369140625
# hist_intersection:  0.539794921875
# hist_return_value:  0.460205078125
# hist_intersection:  0.42340087890625
# hist_return_value:  0.57659912109375
# hist_intersection:  0.4603271484375
# hist_return_value:  0.5396728515625
# hist_intersection:  0.524169921875
# hist_return_value:  0.475830078125
# hist_intersection:  0.2197265625
# hist_return_value:  0.7802734375
# hist_intersection:  0.21209716796875
# hist_return_value:  0.78790283203125
# hist_intersection:  0.8516845703125
# hist_return_value:  0.1483154296875
# hist_intersection:  0.49658203125
# hist_return_value:  0.50341796875
# hist_intersection:  0.59674072265625
# hist_return_value:  0.40325927734375
# hist_intersection:  0.51190185546875
# hist_return_value:  0.48809814453125
# hist_intersection:  0.4345703125
# hist_return_value:  0.5654296875
# hist_intersection:  0.51025390625
# hist_return_value:  0.48974609375
# hist_intersection:  0.52520751953125
# hist_return_value:  0.47479248046875
# hist_intersection:  0.22161865234375
# hist_return_value:  0.77838134765625
# hist_intersection:  0.2193603515625
# hist_return_value:  0.7806396484375
# hist_intersection:  0.6915283203125
# hist_return_value:  0.3084716796875
# hist_intersection:  0.49658203125
# hist_return_value:  0.50341796875
# hist_intersection:  0.6400146484375
# hist_return_value:  0.3599853515625
# hist_intersection:  0.2813720703125
# hist_return_value:  0.7186279296875
# hist_intersection:  0.28814697265625
# hist_return_value:  0.71185302734375
# hist_intersection:  0.47943115234375
# hist_return_value:  0.52056884765625
# hist_intersection:  0.1217041015625
# hist_return_value:  0.8782958984375
# hist_intersection:  0.52960205078125
# hist_return_value:  0.47039794921875
# hist_intersection:  0.62359619140625
# hist_return_value:  0.37640380859375
# hist_intersection:  0.4578857421875
# hist_return_value:  0.5421142578125
# hist_intersection:  0.6982421875
# hist_return_value:  0.3017578125
# hist_intersection:  0.5540771484375
# hist_return_value:  0.4459228515625
# hist_intersection:  0.6600341796875
# hist_return_value:  0.3399658203125
# hist_intersection:  0.44049072265625
# hist_return_value:  0.55950927734375
# hist_intersection:  0.5654296875
# hist_return_value:  0.4345703125
# hist_intersection:  0.461669921875
# hist_return_value:  0.538330078125
# hist_intersection:  0.76434326171875
# hist_return_value:  0.23565673828125
# hist_intersection:  0.19317626953125
# hist_return_value:  0.80682373046875
# hist_intersection:  0.36798095703125
# hist_return_value:  0.63201904296875
# hist_intersection:  0.5555419921875
# hist_return_value:  0.4444580078125
# hist_intersection:  0.25506591796875
# hist_return_value:  0.74493408203125
# hist_intersection:  0.1778564453125
# hist_return_value:  0.8221435546875
# hist_intersection:  0.16522216796875
# hist_return_value:  0.83477783203125
# hist_intersection:  0.30462646484375
# hist_return_value:  0.69537353515625
# hist_intersection:  0.2332763671875
# hist_return_value:  0.7667236328125
# hist_intersection:  0.51202392578125
# hist_return_value:  0.48797607421875
# hist_intersection:  0.65667724609375
# hist_return_value:  0.34332275390625
# hist_intersection:  0.46484375
# hist_return_value:  0.53515625
# hist_intersection:  0.47216796875
# hist_return_value:  0.52783203125
# hist_intersection:  0.61419677734375
# hist_return_value:  0.38580322265625
# hist_intersection:  0.36981201171875
# hist_return_value:  0.63018798828125
# hist_intersection:  0.30120849609375
# hist_return_value:  0.69879150390625
# hist_intersection:  0.20465087890625
# hist_return_value:  0.79534912109375
# hist_intersection:  0.51568603515625
# hist_return_value:  0.48431396484375
# hist_intersection:  0.23944091796875
# hist_return_value:  0.76055908203125
# hist_intersection:  0.370849609375
# hist_return_value:  0.629150390625
# hist_intersection:  0.404296875
# hist_return_value:  0.595703125
# hist_intersection:  0.25799560546875
# hist_return_value:  0.74200439453125
# hist_intersection:  0.6021728515625
# hist_return_value:  0.3978271484375
# hist_intersection:  0.480712890625
# hist_return_value:  0.519287109375
# hist_intersection:  0.301513671875
# hist_return_value:  0.698486328125
# hist_intersection:  0.3914794921875
# hist_return_value:  0.6085205078125
# hist_intersection:  0.486572265625
# hist_return_value:  0.513427734375
# hist_intersection:  0.66265869140625
# hist_return_value:  0.33734130859375
# hist_intersection:  0.61004638671875
# hist_return_value:  0.38995361328125
# hist_intersection:  0.26104736328125
# hist_return_value:  0.73895263671875
# hist_intersection:  0.56951904296875
# hist_return_value:  0.43048095703125
# hist_intersection:  0.29644775390625
# hist_return_value:  0.70355224609375
# hist_intersection:  0.53643798828125
# hist_return_value:  0.46356201171875
# hist_intersection:  0.2578125
# hist_return_value:  0.7421875
# hist_intersection:  0.33770751953125
# hist_return_value:  0.66229248046875
# hist_intersection:  0.65625
# hist_return_value:  0.34375
# hist_intersection:  0.2320556640625
# hist_return_value:  0.7679443359375
# hist_intersection:  0.50689697265625
# hist_return_value:  0.49310302734375
# hist_intersection:  0.61126708984375
# hist_return_value:  0.38873291015625
# hist_intersection:  0.13287353515625
# hist_return_value:  0.86712646484375
# hist_intersection:  0.1859130859375
# hist_return_value:  0.8140869140625
# hist_intersection:  0.47003173828125
# hist_return_value:  0.52996826171875
# hist_intersection:  0.30950927734375
# hist_return_value:  0.69049072265625
# hist_intersection:  0.52203369140625
# hist_return_value:  0.47796630859375
# hist_intersection:  0.603515625
# hist_return_value:  0.396484375
# hist_intersection:  0.47796630859375
# hist_return_value:  0.52203369140625
# hist_intersection:  0.617431640625
# hist_return_value:  0.382568359375
# hist_intersection:  0.59271240234375
# hist_return_value:  0.40728759765625
# hist_intersection:  0.66119384765625
# hist_return_value:  0.33880615234375
# hist_intersection:  0.5006103515625
# hist_return_value:  0.4993896484375
# hist_intersection:  0.5919189453125
# hist_return_value:  0.4080810546875
# hist_intersection:  0.61163330078125
# hist_return_value:  0.38836669921875
# hist_intersection:  0.44512939453125
# hist_return_value:  0.55487060546875
# hist_intersection:  0.2752685546875
# hist_return_value:  0.7247314453125
# hist_intersection:  0.24005126953125
# hist_return_value:  0.75994873046875
# hist_intersection:  0.439208984375
# hist_return_value:  0.560791015625
# hist_intersection:  0.12725830078125
# hist_return_value:  0.87274169921875
# hist_intersection:  0.1964111328125
# hist_return_value:  0.8035888671875
# hist_intersection:  0.135986328125
# hist_return_value:  0.864013671875
# hist_intersection:  0.47039794921875
# hist_return_value:  0.52960205078125
# hist_intersection:  0.14227294921875
# hist_return_value:  0.85772705078125
# hist_intersection:  0.12518310546875
# hist_return_value:  0.87481689453125
# hist_intersection:  0.4334716796875
# hist_return_value:  0.5665283203125
# hist_intersection:  0.50579833984375
# hist_return_value:  0.49420166015625
# hist_intersection:  0.203125
# hist_return_value:  0.796875
# hist_intersection:  0.27935791015625
# hist_return_value:  0.72064208984375
# hist_intersection:  0.1982421875
# hist_return_value:  0.8017578125
# hist_intersection:  0.23968505859375
# hist_return_value:  0.76031494140625
# hist_intersection:  0.36114501953125
# hist_return_value:  0.63885498046875
# hist_intersection:  0.10345458984375
# hist_return_value:  0.89654541015625
# hist_intersection:  0.16156005859375
# hist_return_value:  0.83843994140625
# hist_intersection:  0.21173095703125
# hist_return_value:  0.78826904296875
# hist_intersection:  0.7423095703125
# hist_return_value:  0.2576904296875
# hist_intersection:  0.09197998046875
# hist_return_value:  0.90802001953125
# hist_intersection:  0.10992431640625
# hist_return_value:  0.89007568359375
# hist_intersection:  0.13751220703125
# hist_return_value:  0.86248779296875
# hist_intersection:  0.2266845703125
# hist_return_value:  0.7733154296875
# hist_intersection:  0.3653564453125
# hist_return_value:  0.6346435546875
# hist_intersection:  0.09527587890625
# hist_return_value:  0.90472412109375
# hist_intersection:  0.4837646484375
# hist_return_value:  0.5162353515625
# hist_intersection:  0.16925048828125
# hist_return_value:  0.83074951171875
# hist_intersection:  0.18524169921875
# hist_return_value:  0.81475830078125
# hist_intersection:  0.1649169921875
# hist_return_value:  0.8350830078125
# hist_intersection:  0.0814208984375
# hist_return_value:  0.9185791015625
# hist_intersection:  0.20751953125
# hist_return_value:  0.79248046875
# hist_intersection:  0.11749267578125
# hist_return_value:  0.88250732421875
# hist_intersection:  0.07257080078125
# hist_return_value:  0.92742919921875
# hist_intersection:  0.10308837890625
# hist_return_value:  0.89691162109375
# hist_intersection:  0.08209228515625
# hist_return_value:  0.91790771484375
# hist_intersection:  0.15350341796875
# hist_return_value:  0.84649658203125
# hist_intersection:  0.7462158203125
# hist_return_value:  0.2537841796875
# hist_intersection:  0.16046142578125
# hist_return_value:  0.83953857421875
# hist_intersection:  0.10906982421875
# hist_return_value:  0.89093017578125
# hist_intersection:  0.33966064453125
# hist_return_value:  0.66033935546875
# hist_intersection:  0.4794921875
# hist_return_value:  0.5205078125
# hist_intersection:  0.682861328125
# hist_return_value:  0.317138671875
# hist_intersection:  0.2144775390625
# hist_return_value:  0.7855224609375
# hist_intersection:  0.7451171875
# hist_return_value:  0.2548828125
# hist_intersection:  0.29595947265625
# hist_return_value:  0.70404052734375
# hist_intersection:  0.089599609375
# hist_return_value:  0.910400390625
# hist_intersection:  0.0830078125
# hist_return_value:  0.9169921875
# hist_intersection:  0.39794921875
# hist_return_value:  0.60205078125
# hist_intersection:  0.1595458984375
# ...
# hist_intersection:  0.43963623046875
# hist_return_value:  0.56036376953125
# hist_intersection:  0.09527587890625
# hist_return_value:  0.90472412109375
# hist_intersection:  0.60601806640625
# hist_return_value:  0.39398193359375
# hist_intersection:  0.447021484375
# hist_return_value:  0.552978515625
# hist_intersection:  0.46978759765625
# hist_return_value:  0.53021240234375
# hist_intersection:  0.509521484375
# hist_return_value:  0.490478515625
# hist_intersection:  0.0994873046875
# hist_return_value:  0.9005126953125
# hist_intersection:  0.52166748046875
# hist_return_value:  0.47833251953125
# hist_intersection:  0.08489990234375
# hist_return_value:  0.91510009765625
# hist_intersection:  0.248779296875
# hist_return_value:  0.751220703125
# hist_intersection:  0.17333984375
# hist_return_value:  0.82666015625
# hist_intersection:  0.190673828125
# hist_return_value:  0.809326171875
# hist_intersection:  0.3682861328125
# hist_return_value:  0.6317138671875
# hist_intersection:  0.52093505859375
# hist_return_value:  0.47906494140625
# hist_intersection:  0.59991455078125
# hist_return_value:  0.40008544921875
# hist_intersection:  0.53253173828125
# hist_return_value:  0.46746826171875
# hist_intersection:  0.666015625
# hist_return_value:  0.333984375
# hist_intersection:  0.19366455078125
# hist_return_value:  0.80633544921875
# hist_intersection:  0.4637451171875
# hist_return_value:  0.5362548828125
# hist_intersection:  0.09881591796875
# hist_return_value:  0.90118408203125
# hist_intersection:  0.4071044921875
# hist_return_value:  0.5928955078125
# hist_intersection:  0.184814453125
# hist_return_value:  0.815185546875
# hist_intersection:  0.31365966796875
# hist_return_value:  0.68634033203125
# hist_intersection:  0.0521240234375
# hist_return_value:  0.9478759765625
# hist_intersection:  0.751953125
# hist_return_value:  0.248046875
# hist_intersection:  0.101806640625
# hist_return_value:  0.898193359375
# hist_intersection:  0.371826171875
# hist_return_value:  0.628173828125
# hist_intersection:  0.101318359375
# hist_return_value:  0.898681640625
# hist_intersection:  0.5797119140625
# hist_return_value:  0.4202880859375
# hist_intersection:  0.19818115234375
# hist_return_value:  0.80181884765625
# hist_intersection:  0.43817138671875
# hist_return_value:  0.56182861328125
# hist_intersection:  0.0787353515625
# hist_return_value:  0.9212646484375
# hist_intersection:  0.2713623046875
# hist_return_value:  0.7286376953125
# hist_intersection:  0.18536376953125
# hist_return_value:  0.81463623046875
# hist_intersection:  0.05780029296875
# hist_return_value:  0.94219970703125
# hist_intersection:  0.26165771484375
# hist_return_value:  0.73834228515625
# hist_intersection:  0.52398681640625
# hist_return_value:  0.47601318359375
# hist_intersection:  0.8424072265625
# hist_return_value:  0.1575927734375
# hist_intersection:  0.392578125
# hist_return_value:  0.607421875
# hist_intersection:  0.4334716796875
# hist_return_value:  0.5665283203125
# hist_intersection:  0.09130859375
# hist_return_value:  0.90869140625
# hist_intersection:  0.5062255859375
# hist_return_value:  0.4937744140625
# hist_intersection:  0.062255859375
# hist_return_value:  0.937744140625
# hist_intersection:  0.08721923828125
# hist_return_value:  0.91278076171875
# hist_intersection:  0.4237060546875
# hist_return_value:  0.5762939453125
# hist_intersection:  0.51629638671875
# hist_return_value:  0.48370361328125
# hist_intersection:  0.17144775390625
# hist_return_value:  0.82855224609375
# hist_intersection:  0.0758056640625
# hist_return_value:  0.9241943359375
# hist_intersection:  0.23504638671875
# hist_return_value:  0.76495361328125
# hist_intersection:  0.1009521484375
# hist_return_value:  0.8990478515625
# hist_intersection:  0.35943603515625
# hist_return_value:  0.64056396484375
# hist_intersection:  0.07208251953125
# hist_return_value:  0.92791748046875
# hist_intersection:  0.094970703125
# hist_return_value:  0.905029296875
# hist_intersection:  0.201416015625
# hist_return_value:  0.798583984375
# hist_intersection:  0.70172119140625
# hist_return_value:  0.29827880859375
# hist_intersection:  0.08880615234375
# hist_return_value:  0.91119384765625
# hist_intersection:  0.07342529296875
# hist_return_value:  0.92657470703125
# hist_intersection:  0.079833984375
# hist_return_value:  0.920166015625
# hist_intersection:  0.2001953125
# hist_return_value:  0.7998046875
# hist_intersection:  0.430908203125
# hist_return_value:  0.569091796875
# hist_intersection:  0.10382080078125
# hist_return_value:  0.89617919921875
# hist_intersection:  0.49639892578125
# hist_return_value:  0.50360107421875
# hist_intersection:  0.19720458984375
# hist_return_value:  0.80279541015625
# hist_intersection:  0.15521240234375
# hist_return_value:  0.84478759765625
# hist_intersection:  0.04449462890625
# hist_return_value:  0.95550537109375
# hist_intersection:  0.0760498046875
# hist_return_value:  0.9239501953125
# hist_intersection:  0.16259765625
# hist_return_value:  0.83740234375
# hist_intersection:  0.10333251953125
# hist_return_value:  0.89666748046875
# hist_intersection:  0.0823974609375
# hist_return_value:  0.9176025390625
# hist_intersection:  0.10003662109375
# hist_return_value:  0.89996337890625
# hist_intersection:  0.09490966796875
# hist_return_value:  0.90509033203125
# hist_intersection:  0.16387939453125
# hist_return_value:  0.83612060546875
# hist_intersection:  0.6884765625
# hist_return_value:  0.3115234375
# hist_intersection:  0.10687255859375
# hist_return_value:  0.89312744140625
# hist_intersection:  0.131103515625
# hist_return_value:  0.868896484375
# hist_intersection:  0.30438232421875
# hist_return_value:  0.69561767578125
# hist_intersection:  0.43707275390625
# hist_return_value:  0.56292724609375
# hist_intersection:  0.6920166015625
# hist_return_value:  0.3079833984375
# hist_intersection:  0.23748779296875
# hist_return_value:  0.76251220703125
# hist_intersection:  0.70758056640625
# hist_return_value:  0.29241943359375
# hist_intersection:  0.32330322265625
# hist_return_value:  0.67669677734375
# hist_intersection:  0.06903076171875
# hist_return_value:  0.93096923828125
# hist_intersection:  0.04534912109375
# hist_return_value:  0.95465087890625
# hist_intersection:  0.412841796875
# hist_return_value:  0.587158203125
# hist_intersection:  0.18707275390625
# hist_return_value:  0.81292724609375
# hist_intersection:  0.595703125
# hist_return_value:  0.404296875
# hist_intersection:  0.63092041015625
# hist_return_value:  0.36907958984375
# hist_intersection:  0.4228515625
# hist_return_value:  0.5771484375
# hist_intersection:  0.12738037109375
# hist_return_value:  0.87261962890625
# hist_intersection:  0.5125732421875
# hist_return_value:  0.4874267578125
# hist_intersection:  0.151611328125
# hist_return_value:  0.848388671875
# hist_intersection:  0.3338623046875
# hist_return_value:  0.6661376953125
# hist_intersection:  0.45562744140625
# hist_return_value:  0.54437255859375
# hist_intersection:  0.2314453125
# hist_return_value:  0.7685546875
# hist_intersection:  0.3446044921875
# hist_return_value:  0.6553955078125
# hist_intersection:  0.1375732421875
# hist_return_value:  0.8624267578125
# hist_intersection:  0.383056640625
# hist_return_value:  0.616943359375
# hist_intersection:  0.127685546875
# hist_return_value:  0.872314453125
# hist_intersection:  0.1026611328125
# hist_return_value:  0.8973388671875
# hist_intersection:  0.068603515625
# hist_return_value:  0.931396484375
# hist_intersection:  0.21710205078125
# hist_return_value:  0.78289794921875
# hist_intersection:  0.08599853515625
# hist_return_value:  0.91400146484375
# hist_intersection:  0.20135498046875
# hist_return_value:  0.79864501953125
# hist_intersection:  0.1829833984375
# hist_return_value:  0.8170166015625
# hist_intersection:  0.6673583984375
# hist_return_value:  0.3326416015625
# hist_intersection:  0.7059326171875
# hist_return_value:  0.2940673828125
# hist_intersection:  0.10791015625
# hist_return_value:  0.89208984375
# hist_intersection:  0.591796875
# hist_return_value:  0.408203125
# hist_intersection:  0.1558837890625
# hist_return_value:  0.8441162109375
# hist_intersection:  0.3173828125
# hist_return_value:  0.6826171875
# hist_intersection:  0.3291015625
# hist_return_value:  0.6708984375
# hist_intersection:  0.3477783203125
# hist_return_value:  0.6522216796875
# hist_intersection:  0.071533203125
# hist_return_value:  0.928466796875
# hist_intersection:  0.56109619140625
# hist_return_value:  0.43890380859375
# hist_intersection:  0.1375732421875
# hist_return_value:  0.8624267578125
# hist_intersection:  0.12774658203125
# hist_return_value:  0.87225341796875
# hist_intersection:  0.08697509765625
# hist_return_value:  0.91302490234375
# hist_intersection:  0.22344970703125
# hist_return_value:  0.77655029296875
# hist_intersection:  0.08563232421875
# hist_return_value:  0.91436767578125
# hist_intersection:  0.12677001953125
# hist_return_value:  0.87322998046875
# hist_intersection:  0.08685302734375
# hist_return_value:  0.91314697265625
# hist_intersection:  0.1485595703125
# hist_return_value:  0.8514404296875
# hist_intersection:  0.0631103515625
# hist_return_value:  0.9368896484375
# hist_intersection:  0.05316162109375
# hist_return_value:  0.94683837890625
# hist_intersection:  0.20556640625
# hist_return_value:  0.79443359375
# hist_intersection:  0.57745361328125
# hist_return_value:  0.42254638671875
# hist_intersection:  0.37799072265625
# hist_return_value:  0.62200927734375
# hist_intersection:  0.795166015625
# hist_return_value:  0.204833984375
# hist_intersection:  0.5589599609375
# hist_return_value:  0.4410400390625
# hist_intersection:  0.0899658203125
# hist_return_value:  0.9100341796875
# hist_intersection:  0.4832763671875
# hist_return_value:  0.5167236328125
# hist_intersection:  0.13470458984375
# hist_return_value:  0.86529541015625
# hist_intersection:  0.13104248046875
# hist_return_value:  0.86895751953125
# hist_intersection:  0.45233154296875
# hist_return_value:  0.54766845703125
# hist_intersection:  0.52081298828125
# hist_return_value:  0.47918701171875
# hist_intersection:  0.20989990234375
# hist_return_value:  0.79010009765625
# hist_intersection:  0.12445068359375
# hist_return_value:  0.87554931640625
# hist_intersection:  0.20819091796875
# hist_return_value:  0.79180908203125
# hist_intersection:  0.165283203125
# hist_return_value:  0.834716796875
# hist_intersection:  0.3743896484375
# hist_return_value:  0.6256103515625
# hist_intersection:  0.0648193359375
# hist_return_value:  0.9351806640625
# hist_intersection:  0.1204833984375
# hist_return_value:  0.8795166015625
# hist_intersection:  0.2130126953125
# hist_return_value:  0.7869873046875
# hist_intersection:  0.55224609375
# hist_return_value:  0.44775390625
# hist_intersection:  0.10418701171875
# hist_return_value:  0.89581298828125
# hist_intersection:  0.0643310546875
# hist_return_value:  0.9356689453125
# hist_intersection:  0.11669921875
# hist_return_value:  0.88330078125
# hist_intersection:  0.20343017578125
# hist_return_value:  0.79656982421875
# hist_intersection:  0.3897705078125
# hist_return_value:  0.6102294921875
# hist_intersection:  0.0526123046875
# hist_return_value:  0.9473876953125
# hist_intersection:  0.47216796875
# hist_return_value:  0.52783203125
# hist_intersection:  0.21160888671875
# hist_return_value:  0.78839111328125
# hist_intersection:  0.1790771484375
# hist_return_value:  0.8209228515625
# hist_intersection:  0.10223388671875
# hist_return_value:  0.89776611328125
# hist_intersection:  0.10809326171875
# hist_return_value:  0.89190673828125
# hist_intersection:  0.24530029296875
# hist_return_value:  0.75469970703125
# hist_intersection:  0.118408203125
# hist_return_value:  0.881591796875
# hist_intersection:  0.029052734375
# hist_return_value:  0.970947265625
# hist_intersection:  0.0888671875
# hist_return_value:  0.9111328125
# hist_intersection:  0.037841796875
# hist_return_value:  0.962158203125
# hist_intersection:  0.1673583984375
# hist_return_value:  0.8326416015625
# hist_intersection:  0.528076171875
# hist_return_value:  0.471923828125
# hist_intersection:  0.16729736328125
# hist_return_value:  0.83270263671875
# hist_intersection:  0.078857421875
# hist_return_value:  0.921142578125
# hist_intersection:  0.29022216796875
# hist_return_value:  0.70977783203125
# hist_intersection:  0.47845458984375
# hist_return_value:  0.52154541015625
# hist_intersection:  0.514892578125
# hist_return_value:  0.485107421875
# hist_intersection:  0.16522216796875
# hist_return_value:  0.83477783203125
# hist_intersection:  0.55780029296875
# hist_return_value:  0.44219970703125
# hist_intersection:  0.30322265625
# hist_return_value:  0.69677734375
# hist_intersection:  0.09930419921875
# hist_return_value:  0.90069580078125
# hist_intersection:  0.03814697265625
# hist_return_value:  0.96185302734375
# hist_intersection:  0.41064453125
# hist_return_value:  0.58935546875
# hist_intersection:  0.15789794921875
# hist_return_value:  0.84210205078125
# hist_intersection:  0.58184814453125
# hist_return_value:  0.41815185546875
# hist_intersection:  0.59820556640625
# hist_return_value:  0.40179443359375
# hist_intersection:  0.4903564453125
# hist_return_value:  0.5096435546875
# hist_intersection:  0.1220703125
# hist_return_value:  0.8779296875
# hist_intersection:  0.54400634765625
# hist_return_value:  0.45599365234375
# hist_intersection:  0.19036865234375
# hist_return_value:  0.80963134765625
# hist_intersection:  0.37176513671875
# hist_return_value:  0.62823486328125
# hist_intersection:  0.4619140625
# hist_return_value:  0.5380859375
# hist_intersection:  0.20367431640625
# hist_return_value:  0.79632568359375
# hist_intersection:  0.3671875
# hist_return_value:  0.6328125
# hist_intersection:  0.14959716796875
# hist_return_value:  0.85040283203125
# hist_intersection:  0.420166015625
# hist_return_value:  0.579833984375
# hist_intersection:  0.12005615234375
# hist_return_value:  0.87994384765625
# hist_intersection:  0.11883544921875
# hist_return_value:  0.88116455078125
# hist_intersection:  0.0970458984375
# hist_return_value:  0.9029541015625
# hist_intersection:  0.1939697265625
# hist_return_value:  0.8060302734375
# hist_intersection:  0.08209228515625
# hist_return_value:  0.91790771484375
# hist_intersection:  0.216552734375
# hist_return_value:  0.783447265625
# hist_intersection:  0.19598388671875
# hist_return_value:  0.80401611328125
# hist_intersection:  0.5413818359375
# hist_return_value:  0.4586181640625
# hist_intersection:  0.58392333984375
# hist_return_value:  0.41607666015625
# hist_intersection:  0.1243896484375
# hist_return_value:  0.8756103515625
# hist_intersection:  0.57611083984375
# hist_return_value:  0.42388916015625
# hist_intersection:  0.1380615234375
# hist_return_value:  0.8619384765625
# hist_intersection:  0.3333740234375
# hist_return_value:  0.6666259765625
# hist_intersection:  0.1925048828125
# hist_return_value:  0.8074951171875
# hist_intersection:  0.532470703125
# hist_return_value:  0.467529296875
# hist_intersection:  0.15087890625
# hist_return_value:  0.84912109375
# hist_intersection:  0.53814697265625
# hist_return_value:  0.46185302734375
# hist_intersection:  0.13641357421875
# hist_return_value:  0.86358642578125
# hist_intersection:  0.12677001953125
# hist_return_value:  0.87322998046875
# hist_intersection:  0.040771484375
# hist_return_value:  0.959228515625
# hist_intersection:  0.2049560546875
# hist_return_value:  0.7950439453125
# hist_intersection:  0.0966796875
# hist_return_value:  0.9033203125
# hist_intersection:  0.14501953125
# hist_return_value:  0.85498046875
# hist_intersection:  0.13031005859375
# hist_return_value:  0.86968994140625
# hist_intersection:  0.1136474609375
# hist_return_value:  0.8863525390625
# hist_intersection:  0.10784912109375
# hist_return_value:  0.89215087890625
# hist_intersection:  0.01959228515625
# hist_return_value:  0.98040771484375
# hist_intersection:  0.203857421875
# hist_return_value:  0.796142578125
# hist_intersection:  0.5438232421875
# hist_return_value:  0.4561767578125
# hist_intersection:  0.358154296875
# hist_return_value:  0.641845703125
# hist_intersection:  0.53497314453125
# hist_return_value:  0.46502685546875
# hist_intersection:  0.76025390625
# hist_return_value:  0.23974609375
# Indexes of correct retrieved images is:
#   [ 0  1  2  3  4  5  6  8  9 10 11 12 13 14 16 17 18 19 21 22 23 24 26 27
#  28 29 30 32 33 36 37 38 39 40 42 43 44 45 46 48 49 50 51 52 54 55 56 57
#  58 59 60 64 66 69 70 71 72 74 75 77 79 80 81 82 83 84 85 86 87 88]
# The Recognition rate is 0.7865168539325843

# %% [markdown]
# #### Exercise 3.b **(3 Points)**
# Implement a function **show_neighbors** which takes a list of model images and a list of
# query images and for each query image visualizes several model images which are closest to the query image
# according to the specified distance metric. Use the function find best match in your implementation. See the Figure below for example of the output.
#
# ![](https://drive.google.com/uc?export=view&id=1qlPbNzh92u9EU4kzNMbHg0uRgSk4AnRO)

# %%
def show_neighbors(model_images, query_images, dist_type, hist_type, num_bins):
  '''
  For each image file from 'query_images' find and visualize the 5 nearest images from 'model_image'.

  Note: use the previously implemented function 'find_best_match'
  Note: use subplot command to show all the images in the same Python figure, one row per query image
  
  '''
  
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  
#   model_image_list = []
#   for i in model_images:
#     img = Image.open(i)
#     img = np.array(img)
#     model_image_list.append(img)
#   model_image_hists = compute_histograms(model_image_list, hist_type, False, num_bins)

#   query_image_list = []
#   for i in query_images:
#     img = Image.open(i)
#     img = np.array(img)
#     query_image_list.append(img)
#   query_image_hists = compute_histograms(query_image_list, hist_type, False, num_bins)
  
#   D = []
#   for q in range(len(query_image_hists)):
#     l = []
#     for m in range(len(model_image_hists)):
#         d = get_dist_by_name(model_image_hists[q], model_image_hists[m], 'l2')
#         l.append(d)
#     D.append(l)
#   D = np.array(D)
  best_match, D = find_best_match(model_images, query_images, dist_type, hist_type, num_bins)
  l = D.transpose()
  x= []
  for i in range(len(l)):
    x.append(np.argsort(l[i])[:5])
  x = np.array(x)

  plt.figure()
  f, ax = plt.subplots(3,6)
  for i in range(len(x)):
    img = Image.open(query_images[i])
    img = np.array(img)
    ax[i][0].imshow(img)
    for j in range(len(x[i])):
        img = Image.open(model_images[x[i][j]])
        img = np.array(img)
        ax[i][j + 1].imshow(img)
  plt.show()
  return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## visualize nearest neighbors
query_images_vis = [query_images[i] for i in np.array([0,4,9])]
show_neighbors(model_images, query_images_vis, dist_type, hist_type, num_bins)

# %% [markdown]
# #### Metric
#  Use the function find best match to compute recognition rate for different combinations of distance and
# histogram functions. The recognition rate is given by a ratio between number of correct matches and total
# number of query images.

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
num_correct = sum(best_match == range(len(query_images)))
print('number of correct matches: %d (%f)\n'% (num_correct, 1.0 * num_correct / len(query_images)))
# Out:
# number of correct matches: 1 (0.011236)

# %% [markdown]
# ### Report **(4 Points)**
#
# Experiment with different functions and numbers of histogram bins, try to find
# combination that works best. **Submit the summary of your experiments in a report as part of your solution.**

# %% [markdown]
# **Write your Report here**
#
#
# |  | Number of Bins | Metric(Distance Metric) | Accuracy |
# |---|---|---|---|
# | 1 |  |  |  |
# | 2 |  |  |  |
# | 3 |  |  |  |
# | ... |  |  |  |

# %% [markdown]
# ## Question 4: [K-Means]((https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1))
# ###(Bonus question for **5 Points**, not compulsory)
#
# Recolor the original images and Query images by using Kmeans. And find the best matches between the two.
#
# There are several way to preprocess an image, and in this exrcise you will work with "recoloration". Given an image, you will use a Kmeans model to transform it, and use the same model to transform the images that belongs to the model folder, then repeat the previous to exercises to extract the RGB hist and find the best match. We'll provide the method to fit a KMeans model on an image and to transform an image given a KMeans model. You should then use these functions, applying them on the query images (to retrieve recolored images and a KMeans_model for each query image) and on the model images. Pay attention on the fact that you should use a model fitted on a query image on the whole model folder to have coherent results.
#
# In the following example, the KMeans model has been fitted on three different images: [Row 1] then these models are used to transform original images to recolored images [Row 2:4]
#
# ![](https://drive.google.com/uc?export=view&id=1m0Wu2n12BflIwMHL1g3LUxHurotxrPWr)

# %% [markdown]
# #### Exercise 4 - Code **(3 Points)**

# %%
from sklearn.cluster import KMeans
import numpy as np

def fitting_kmeans(query, K):
  '''
  fit a Kmeans model on 1 image.
  return the recolored image and the KM model
  '''
  shape_ = query.shape

  kmeans = KMeans(K)
  data = query.reshape(-1, 3)
  kmeans.fit(data)
  query_recolored = kmeans.cluster_centers_[kmeans.predict(data)]

  return query_recolored.reshape(shape_), kmeans


def apply_kmeans(km_model, model_image):
  '''
  transform with a Kmeans model 1 image.
  return the recolored image.
  '''

  shape_ = model_image.shape
  data = model_image.reshape(-1, 3)
  img_recolored = km_model.cluster_centers_[km_model.predict(data)]

  return img_recolored.reshape(shape_)

# %%
def compute_KM_histograms(image_list, num_bins=10):
  '''
  Function to compute histograms of a list of images.
  Leverage the "rgb_hist" function previously coded.
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################
  image_hists = []
  for i in image_list:
    ih=rgb_hist(i)
    image_hists.append(ih)

  return image_hists

# %%
def compute_KMeans(model_list, query_list, K):
    '''
    Function to compute the recolored images from both query and 
    model lists. You should:
    1. Apply the fitting metod to queries retrieving the ist of recolored
       queries and KMeans models.
    2. Apply the transforming method on all the images in the model folder
       for each KMeans you fitted in the previous step.
    3. Return the 2 lists of recolored images.
    '''
    query_recolored_imgs = []
    query_km_models = []
    model_recolored_imgs = []

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    for query in query_list:
        qc,kc=fitting_kmeans(query,K)
        query_recolored_imgs.append(qc)
        query_km_models.append(kc)
        
    for mi in model_list and km in query_km_models:
        model_recolored_imgs.append(apply_kmeans(km,mi))    

    return query_recolored_imgs, model_recolored_imgs


def compute_recolored_hists(query_recolored, model_recolored):
    '''
    Function to compute the histograms of lists of images.
    Use the compute_KM_histograms function.
    '''

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################

    query_hists= compute_KM_histograms(query_recolored)
    model_hists= compute_KM_histograms(model_recolored)

    return query_hists, model_hists


def compute_matching(q_hists, m_hists, dist_type):
    '''
    Function to compute the scores among several histograms.
    Similarly to find_best_match function you have previously defined,
    this function will return the best_match list.

    EXTRA: add the 'all' dist_type wich compute the scores for all 3 
    kind of distances, exploiting the strength of modulation!
    '''

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    best_match = []
    D = []
    for q in range(len(q_hists)):
        min = np.inf
        idx = -1
        l = []
        for m in range(len(m_hists)):
            d = get_dist_by_name(m_hists[q], m_hists[m], dist_type)
            l.append(d)
            if (d < min): 
                min = d
                idx = m
        best_match.append(idx)
        D.append(l)
    D = np.array(D)
    D = np.transpose(D)
    best_match = np.array(best_match)

    return best_match

def print_corrects_KM(match, tot_q_images, dist_type, K):
    '''
    Function to print the results.
    Input:
    match: the best_match results
    tot_images: len(model_images)
    dist_type: among 'l2', 'intersect' and 'chi2' (EXTRA: 'all')
    K: K-Means parameter

    last three args should be expicitly printed by this function.

    Example of Output:

    Settings: K=30, dist=chi2
    Results: Number of correct matches: 58/89 (65.17%)
    '''

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    print("Setting: K=",K,", dist=",dist_type)
    print("Results: Number of correct matches:", match,"/", total_q_images,"(", match/total_q_images,"%)")

def KM_matching(model_imgs, query_imgs, dist_type, K):
    '''
    Use all the functions you have just defined to print the results.
    '''

    #####################################################
    ##                 YOUR CODE HERE                  ##
    #####################################################
    compute_KM_histograms(query_imgs)
    query_rc,model_rc=compute_KMeans(model_imgs,query_imgs,K)
    query_ht,model_ht=compute_recolored_hists(query_rc,model_rc)
    bm=compute_matching(query_ht,model_ht,dist_type)
    match=len(bm)
    t_images=len(query_imgs)
    to_return=print_corrects_KM(match,t_images,dist_type,K)

    return to_return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
query_images, model_images = read_files()

K = 30
dist_type = 'all'

KM_matching(model_images, query_images, dist_type, K)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/4053599660.py in <module>
#       4 dist_type = 'all'
#       5
# ----> 6 KM_matching(model_images, query_images, dist_type, K)
#
# ~\AppData\Local\Temp/ipykernel_9468/4238365376.py in KM_matching(model_imgs, query_imgs, dist_type, K)
#     107     ##                 YOUR CODE HERE                  ##
#     108     #####################################################
# --> 109     compute_KM_histograms(query_imgs)
#     110     query_rc,model_rc=compute_KMeans(model_imgs,query_imgs,K)
#     111     query_ht,model_ht=compute_recolored_hists(query_rc,model_rc)
#
# ~\AppData\Local\Temp/ipykernel_9468/156049179.py in compute_KM_histograms(image_list, num_bins)
#      10   image_hists = []
#      11   for i in image_list:
# ---> 12     ih=rgb_hist(i)
#      13     image_hists.append(ih)
#      14
#
# ~\AppData\Local\Temp/ipykernel_9468/2675411977.py in rgb_hist(img_color_double, num_bins, show_verbose)
#      13       - their B values fall in bin 5
#      14     '''
# ---> 15     img_color_double = np.reshape(img_color_double, (16384,3))
#      16     img_color_double = list(map(divide255, img_color_double))
#      17
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      41     except AttributeError:
#      42         wrap = None
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#      44     if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# ValueError: cannot reshape array of size 1 into shape (16384,3)

# %% [markdown]
# #### Report **(2 Points)**
#
# Experiment with different functions and numbers of clusters, try to find
# combination that works best. **Submit the summary of your experiments in a report as part of your solution.**

# %% [markdown]
# **Write your Report here**
#
#
# |  | Number of Clusters | Metric(Distance Metric) | Accuracy |
# |---|---|---|---|
# | 1 |  |  |  |
# | 2 |  |  |  |
# | 3 |  |  |  |
# | ... |  |  |  |
